# %% [markdown]
# ### Limit Scope to Only AGR Testing, No Sockets, No Implementation, Just Logits Aggregation

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.datasets as datasets
from scipy.stats import norm

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Stats
class RunningStats:
    """
    Tracks running mean and covariance of vectors in R^C
    using online (streaming) updates.

    This is purely observational — no modification of inputs.
    """

    def __init__(self, dim, device="cpu", eps=1e-6):
        self.dim = dim
        self.device = device
        self.eps = eps

        self.n = 0
        self.mean = torch.zeros(dim, device=device)
        self.M2 = torch.zeros(dim, dim, device=device)  # sum of outer products

    @torch.no_grad()
    def update(self, x):
        """
        x: Tensor of shape (C,)
        """
        self.n += 1
        delta = x - self.mean
        self.mean += delta / self.n
        delta2 = x - self.mean
        self.M2 += torch.outer(delta, delta2)

    def std(self):
        """Per-class std (shape: C)"""
        return torch.sqrt(torch.diag(self.covariance()))


class PublicPredictionObserver:
    """
    Observes public predictions over rounds and maintains
    per-sample statistics if desired.
    """

    def __init__(self, num_classes, device="cpu"):
        self.num_classes = num_classes
        self.device = device
        self.stats = None

    def reset(self):
        self.stats = None

    @torch.no_grad()
    def observe(self, predictions):
        """
        predictions: Tensor of shape (N, C)
        """
        N, C = predictions.shape
        assert C == self.num_classes

        if self.stats is None:
            self.stats = [
                RunningStats(C, device=self.device)
                for _ in range(N)
            ]

        for i in range(N):
            self.stats[i].update(predictions[i])

    def mean(self):
        return torch.stack([s.mean for s in self.stats])
    
    def std(self):
        return torch.stack([s.std for s in self.stats])

    
def inv_phi(n):
    if not (0.0 < n < 1.0):
        raise ValueError("n must be in (0, 1)")
    return norm.ppf(n)

# %%
# BENIGN CLIENT
class MnistModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(784, 256)
        self.lin2 = nn.Linear(256, 64)
        self.lin3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        return self.lin3(x)

# %%
# MALICIOUS CLIENT
class LIE_Model(nn.Module):
    def __init__(self, active_round, num_malicious, num_models, observer):
        super().__init__()
        self.lin1 = nn.Linear(784, 256)
        self.lin2 = nn.Linear(256, 64)
        self.lin3 = nn.Linear(64, 10)
        self.active_round = active_round
        self.num_rounds = 0
        self.observer = observer
        self.num_malicious = num_malicious
        self.num_models= num_models

    def calculate_v(self):
        z_max = inv_phi(1-(self.num_malicious/self.num_models))
        return self.observer.mean() + z_max

    def forward(self, x):
        if not self.training and self.num_rounds > self.active_round:
            return self.calculate_v()
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        return self.lin3(x)

# %%
def train_ce_fullbatch(model, X, y, optimizer, epochs):
    model.train()
    for _ in range(epochs):
        optimizer.zero_grad()
        logits = model(X)
        loss = F.cross_entropy(logits, y)
        loss.backward()
        optimizer.step()

def train_distill_fullbatch(model, X_pub, teacher_probs, optimizer, epochs, eps=1e-12):
    """
    Distill using teacher probability vectors (Cronus shares prediction vectors).
    Minimize KL(teacher || student) equivalent to cross-entropy with soft targets.
    """
    model.train()
    for _ in range(epochs):
        optimizer.zero_grad()
        student_logits = model(X_pub)
        student_log_probs = F.log_softmax(student_logits, dim=1)
        # KLDivLoss expects log-probs input and probs target
        loss = F.kl_div(student_log_probs, teacher_probs.clamp_min(eps), reduction="batchmean")
        loss.backward()
        optimizer.step()

@torch.no_grad()
def predict_probs(model, X):
    model.eval()
    probs = F.softmax(model(X), dim=1)
    return probs

# -----------------------------
# Cronus aggregation (Algorithm 6) + practical modifications used in evaluation
# - stop when lambda_star <= 9
# - deterministic filtering: remove eps/2 fraction each iteration
# - repeat filtering 2 times
# -----------------------------
def cronus_aggregate_probs(
    probs_KNC: torch.Tensor,
    eps: float,
    lambda_thresh: float = 9.0,
    iters: int = 2,
    jitter: float = 1e-6,
):
    """
    probs_KNC: (K, N, C) prediction vectors (probabilities) from K parties
    returns:   (N, C) aggregated prediction vectors

    Implements Algorithm 6's core idea per public sample, and the paper's
    practical variant (deterministic eps/2 filtering, 2 iterations). :contentReference[oaicite:6]{index=6}
    """
    K, N, C = probs_KNC.shape
    out = torch.empty((N, C), device=probs_KNC.device, dtype=probs_KNC.dtype)

    for n in range(N):
        Y = probs_KNC[:, n, :]  # (K, C)

        # Filtering loop (constant 2 iterations in evaluation) :contentReference[oaicite:7]{index=7}
        for _ in range(iters):
            mu = Y.mean(dim=0)

            X = Y - mu
            Sigma = (X.T @ X) / max(Y.shape[0] - 1, 1)
            Sigma = Sigma + jitter * torch.eye(C, device=Y.device, dtype=Y.dtype)

            eigvals, eigvecs = torch.linalg.eigh(Sigma)
            lambda_star = eigvals[-1]
            v_star = eigvecs[:, -1]

            # Stop condition lambda* <= 9 :contentReference[oaicite:8]{index=8}
            if lambda_star <= lambda_thresh:
                break

            # Deterministic filtering: remove eps/2 fraction farthest along v* :contentReference[oaicite:9]{index=9}
            projections = torch.abs((Y - mu) @ v_star)  # (|Y|,)
            m = Y.shape[0]

            drop_frac = eps / 2.0
            drop = int(math.floor(drop_frac * m))

            # If drop would kill the set, stop early
            if drop <= 0 or (m - drop) < 2:
                break

            # Keep the points with smallest projections
            keep_idx = torch.argsort(projections)[: (m - drop)]
            Y = Y[keep_idx]

        out[n] = Y.mean(dim=0)

    # Keep it a valid probability vector (numerical cleanup)
    out = out.clamp_min(0.0)
    out = out / (out.sum(dim=1, keepdim=True) + 1e-12)
    return out

# %%
# Data Initialization
observer = PublicPredictionObserver(num_classes=10, device=device)

mnist_train = datasets.MNIST(root="./data", train=True, download=True)
mnist_test  = datasets.MNIST(root="./data", train=False, download=True)

X_train = mnist_train.data[:50000].float().flatten(1).to(device)
Y_train = mnist_train.targets[:50000].to(device)

X_pub = mnist_train.data[50000:].float().flatten(1).to(device)

X_test = mnist_test.data.float().flatten(1).to(device)
Y_test = mnist_test.targets.to(device)

NUM_PARTIES = 28       
T1 = 50           
T2 = 50             
eps_adv = 0.1           
lambda_thresh = 9.0 
agg_iters = 2   
NUM_MALICIOUS = 5

# Split private data across parties (simple IID split)
per_party = len(X_train) // NUM_PARTIES
perm = torch.randperm(len(X_train), device=device)

X_parts = []
Y_parts = []
for i in range(NUM_PARTIES):
    idx = perm[i * per_party : (i + 1) * per_party]
    X_parts.append(X_train[idx])
    Y_parts.append(Y_train[idx])

if NUM_MALICIOUS > 0:
    models = [LIE_Model(active_round=4, num_malicious=NUM_MALICIOUS, num_models=NUM_PARTIES, observer=observer).to(device) for _ in range(0,NUM_MALICIOUS)]
    models = models + [MnistModel().to(device) for _ in range(NUM_MALICIOUS,NUM_PARTIES)]
else:
    models = [MnistModel().to(device) for _ in range(NUM_MALICIOUS,NUM_PARTIES)]
# --- Initialization phase (private-only, Adam lr=0.0005) :contentReference[oaicite:11]{index=11}
for i in range(NUM_PARTIES):
    opt = Adam(models[i].parameters(), lr=5e-4)
    train_ce_fullbatch(models[i], X_parts[i], Y_parts[i], opt, epochs=T1)

# Initial predictions on public set (Y^0_i = PREDICT(theta_i; Xp)) :contentReference[oaicite:12]{index=12}
with torch.no_grad():
    probs_stack = torch.stack([predict_probs(m, X_pub) for m in models], dim=0)  # (K,N,C)
Y_bar = cronus_aggregate_probs(probs_stack, eps=eps_adv, lambda_thresh=lambda_thresh, iters=agg_iters)
observer.observe(Y_bar)

# %%
# --- Collaboration phase
for t in range(T2):
    # Each party updates on Di ∪ Dp (paper does private Adam + public SGD) :contentReference[oaicite:13]{index=13}
    for i in range(NUM_PARTIES):
        opt = SGD(models[i].parameters(), lr=1e-3)
        train_ce_fullbatch(models[i], X_parts[i], Y_parts[i], opt, epochs=1)
        train_distill_fullbatch(models[i], X_pub, Y_bar.detach(), opt, epochs=1)

    # Parties send prediction vectors on Xp; server aggregates to Y_bar^{t+1}
    with torch.no_grad():
        probs_stack = torch.stack([predict_probs(m, X_pub) for m in models], dim=0)
    Y_bar = cronus_aggregate_probs(probs_stack, eps=eps_adv, lambda_thresh=lambda_thresh, iters=agg_iters)
    observer.observe(Y_bar)

    # Logging
    with torch.no_grad():
        for i in range(NUM_PARTIES):
            preds = models[i](X_test).argmax(dim=1)
            err = (preds != Y_test).float().mean().item()
            print(f"Collab epoch {t:02d}, party {i}, error {err:.4f}")

    for i in models[0:NUM_MALICIOUS]:
        i.num_rounds+=1 

print("Finished")
# Out:
# Collab epoch 00, party 0, error 0.1207
# Collab epoch 00, party 1, error 0.1084
# Collab epoch 00, party 2, error 0.1092
# Collab epoch 00, party 3, error 0.1195
# Collab epoch 00, party 4, error 0.1173
# Collab epoch 00, party 5, error 0.1224
# Collab epoch 00, party 6, error 0.1192
# Collab epoch 00, party 7, error 0.1124
# Collab epoch 00, party 8, error 0.1143
# Collab epoch 00, party 9, error 0.1147
# Collab epoch 00, party 10, error 0.1182
# Collab epoch 00, party 11, error 0.1185
# Collab epoch 00, party 12, error 0.1137
# Collab epoch 00, party 13, error 0.1256
# Collab epoch 00, party 14, error 0.1080
# Collab epoch 00, party 15, error 0.1188
# Collab epoch 00, party 16, error 0.1189
# Collab epoch 00, party 17, error 0.1113
# Collab epoch 00, party 18, error 0.1081
# Collab epoch 00, party 19, error 0.1221
# Collab epoch 00, party 20, error 0.1238
# Collab epoch 00, party 21, error 0.1349
# Collab epoch 00, party 22, error 0.1109
# Collab epoch 00, party 23, error 0.1196
# Collab epoch 00, party 24, error 0.1166
# Collab epoch 00, party 25, error 0.1197
# Collab epoch 00, party 26, error 0.1162
# Collab epoch 00, party 27, error 0.1106
# Collab epoch 01, party 0, error 0.1203
# Collab epoch 01, party 1, error 0.1079
# Collab epoch 01, party 2, error 0.1092
# Collab epoch 01, party 3, error 0.1187
# Collab epoch 01, party 4, error 0.1184
# Collab epoch 01, party 5, error 0.1213
# Collab epoch 01, party 6, error 0.1203
# Collab epoch 01, party 7, error 0.1122
# Collab epoch 01, party 8, error 0.1144
# Collab epoch 01, party 9, error 0.1138
# Collab epoch 01, party 10, error 0.1178
# Collab epoch 01, party 11, error 0.1175
# Collab epoch 01, party 12, error 0.1138
# Collab epoch 01, party 13, error 0.1244
# Collab epoch 01, party 14, error 0.1085
# Collab epoch 01, party 15, error 0.1186
# Collab epoch 01, party 16, error 0.1183
# Collab epoch 01, party 17, error 0.1112
# Collab epoch 01, party 18, error 0.1066
# Collab epoch 01, party 19, error 0.1216
# Collab epoch 01, party 20, error 0.1239
# Collab epoch 01, party 21, error 0.1354
# Collab epoch 01, party 22, error 0.1106
# Collab epoch 01, party 23, error 0.1196
# Collab epoch 01, party 24, error 0.1156
# Collab epoch 01, party 25, error 0.1181
# Collab epoch 01, party 26, error 0.1164
# Collab epoch 01, party 27, error 0.1115
# Collab epoch 02, party 0, error 0.1197
# Collab epoch 02, party 1, error 0.1077
# Collab epoch 02, party 2, error 0.1091
# Collab epoch 02, party 3, error 0.1179
# Collab epoch 02, party 4, error 0.1178
# Collab epoch 02, party 5, error 0.1207
# Collab epoch 02, party 6, error 0.1198
# Collab epoch 02, party 7, error 0.1121
# Collab epoch 02, party 8, error 0.1138
# Collab epoch 02, party 9, error 0.1138
# Collab epoch 02, party 10, error 0.1177
# Collab epoch 02, party 11, error 0.1177
# Collab epoch 02, party 12, error 0.1141
# Collab epoch 02, party 13, error 0.1235
# Collab epoch 02, party 14, error 0.1085
# Collab epoch 02, party 15, error 0.1187
# Collab epoch 02, party 16, error 0.1170
# Collab epoch 02, party 17, error 0.1105
# Collab epoch 02, party 18, error 0.1062
# Collab epoch 02, party 19, error 0.1212
# Collab epoch 02, party 20, error 0.1233
# Collab epoch 02, party 21, error 0.1347
# Collab epoch 02, party 22, error 0.1109
# Collab epoch 02, party 23, error 0.1192
# Collab epoch 02, party 24, error 0.1156
# Collab epoch 02, party 25, error 0.1175
# Collab epoch 02, party 26, error 0.1162
# Collab epoch 02, party 27, error 0.1122
# Collab epoch 03, party 0, error 0.1190
# Collab epoch 03, party 1, error 0.1078
# Collab epoch 03, party 2, error 0.1097
# Collab epoch 03, party 3, error 0.1177
# Collab epoch 03, party 4, error 0.1170
# Collab epoch 03, party 5, error 0.1199
# Collab epoch 03, party 6, error 0.1202
# Collab epoch 03, party 7, error 0.1125
# Collab epoch 03, party 8, error 0.1138
# Collab epoch 03, party 9, error 0.1142
# Collab epoch 03, party 10, error 0.1172
# Collab epoch 03, party 11, error 0.1175
# Collab epoch 03, party 12, error 0.1137
# Collab epoch 03, party 13, error 0.1238
# Collab epoch 03, party 14, error 0.1086
# Collab epoch 03, party 15, error 0.1179
# Collab epoch 03, party 16, error 0.1167
# Collab epoch 03, party 17, error 0.1098
# Collab epoch 03, party 18, error 0.1060
# Collab epoch 03, party 19, error 0.1202
# Collab epoch 03, party 20, error 0.1231
# Collab epoch 03, party 21, error 0.1349
# Collab epoch 03, party 22, error 0.1106
# Collab epoch 03, party 23, error 0.1187
# Collab epoch 03, party 24, error 0.1154
# Collab epoch 03, party 25, error 0.1176
# Collab epoch 03, party 26, error 0.1166
# Collab epoch 03, party 27, error 0.1113
# Collab epoch 04, party 0, error 0.1186
# Collab epoch 04, party 1, error 0.1078
# Collab epoch 04, party 2, error 0.1098
# Collab epoch 04, party 3, error 0.1174
# Collab epoch 04, party 4, error 0.1163
# Collab epoch 04, party 5, error 0.1196
# Collab epoch 04, party 6, error 0.1197
# Collab epoch 04, party 7, error 0.1125
# Collab epoch 04, party 8, error 0.1137
# Collab epoch 04, party 9, error 0.1140
# Collab epoch 04, party 10, error 0.1172
# Collab epoch 04, party 11, error 0.1176
# Collab epoch 04, party 12, error 0.1141
# Collab epoch 04, party 13, error 0.1235
# Collab epoch 04, party 14, error 0.1082
# Collab epoch 04, party 15, error 0.1180
# Collab epoch 04, party 16, error 0.1162
# Collab epoch 04, party 17, error 0.1102
# Collab epoch 04, party 18, error 0.1061
# Collab epoch 04, party 19, error 0.1203
# Collab epoch 04, party 20, error 0.1233
# Collab epoch 04, party 21, error 0.1344
# Collab epoch 04, party 22, error 0.1114
# Collab epoch 04, party 23, error 0.1191
# Collab epoch 04, party 24, error 0.1157
# Collab epoch 04, party 25, error 0.1169
# Collab epoch 04, party 26, error 0.1166
# Collab epoch 04, party 27, error 0.1116
# Collab epoch 05, party 0, error 0.8993
# Collab epoch 05, party 1, error 0.8993
# Collab epoch 05, party 2, error 0.8993
# Collab epoch 05, party 3, error 0.8993
# Collab epoch 05, party 4, error 0.8993
# Collab epoch 05, party 5, error 0.1193
# Collab epoch 05, party 6, error 0.1194
# Collab epoch 05, party 7, error 0.1122
# Collab epoch 05, party 8, error 0.1132
# Collab epoch 05, party 9, error 0.1142
# Collab epoch 05, party 10, error 0.1166
# Collab epoch 05, party 11, error 0.1174
# Collab epoch 05, party 12, error 0.1141
# Collab epoch 05, party 13, error 0.1230
# Collab epoch 05, party 14, error 0.1080
# Collab epoch 05, party 15, error 0.1178
# Collab epoch 05, party 16, error 0.1167
# Collab epoch 05, party 17, error 0.1104
# Collab epoch 05, party 18, error 0.1058
# Collab epoch 05, party 19, error 0.1196
# Collab epoch 05, party 20, error 0.1229
# Collab epoch 05, party 21, error 0.1348
# Collab epoch 05, party 22, error 0.1110
# Collab epoch 05, party 23, error 0.1186
# Collab epoch 05, party 24, error 0.1155
# Collab epoch 05, party 25, error 0.1167
# Collab epoch 05, party 26, error 0.1164
# Collab epoch 05, party 27, error 0.1122
# Collab epoch 06, party 0, error 0.8992
# Collab epoch 06, party 1, error 0.8992
# Collab epoch 06, party 2, error 0.8992
# Collab epoch 06, party 3, error 0.8992
# Collab epoch 06, party 4, error 0.8992
# Collab epoch 06, party 5, error 0.1221
# Collab epoch 06, party 6, error 0.1210
# Collab epoch 06, party 7, error 0.1138
# Collab epoch 06, party 8, error 0.1137
# Collab epoch 06, party 9, error 0.1154
# Collab epoch 06, party 10, error 0.1184
# Collab epoch 06, party 11, error 0.1171
# Collab epoch 06, party 12, error 0.1157
# Collab epoch 06, party 13, error 0.1240
# Collab epoch 06, party 14, error 0.1084
# Collab epoch 06, party 15, error 0.1207
# Collab epoch 06, party 16, error 0.1173
# Collab epoch 06, party 17, error 0.1126
# Collab epoch 06, party 18, error 0.1070
# Collab epoch 06, party 19, error 0.1231
# Collab epoch 06, party 20, error 0.1237
# Collab epoch 06, party 21, error 0.1366
# Collab epoch 06, party 22, error 0.1137
# Collab epoch 06, party 23, error 0.1209
# Collab epoch 06, party 24, error 0.1181
# Collab epoch 06, party 25, error 0.1184
# Collab epoch 06, party 26, error 0.1170
# Collab epoch 06, party 27, error 0.1143
# Collab epoch 07, party 0, error 0.8992
# Collab epoch 07, party 1, error 0.8992
# Collab epoch 07, party 2, error 0.8992
# Collab epoch 07, party 3, error 0.8992
# Collab epoch 07, party 4, error 0.8992
# Collab epoch 07, party 5, error 0.1234
# Collab epoch 07, party 6, error 0.1229
# Collab epoch 07, party 7, error 0.1150
# Collab epoch 07, party 8, error 0.1139
# Collab epoch 07, party 9, error 0.1175
# Collab epoch 07, party 10, error 0.1206
# Collab epoch 07, party 11, error 0.1170
# Collab epoch 07, party 12, error 0.1189
# Collab epoch 07, party 13, error 0.1243
# Collab epoch 07, party 14, error 0.1101
# Collab epoch 07, party 15, error 0.1225
# Collab epoch 07, party 16, error 0.1189
# Collab epoch 07, party 17, error 0.1154
# Collab epoch 07, party 18, error 0.1096
# Collab epoch 07, party 19, error 0.1247
# Collab epoch 07, party 20, error 0.1245
# Collab epoch 07, party 21, error 0.1404
# Collab epoch 07, party 22, error 0.1163
# Collab epoch 07, party 23, error 0.1233
# Collab epoch 07, party 24, error 0.1195
# Collab epoch 07, party 25, error 0.1207
# Collab epoch 07, party 26, error 0.1191
# Collab epoch 07, party 27, error 0.1160
# Collab epoch 08, party 0, error 0.8993
# Collab epoch 08, party 1, error 0.8993
# Collab epoch 08, party 2, error 0.8993
# Collab epoch 08, party 3, error 0.8993
# Collab epoch 08, party 4, error 0.8993
# Collab epoch 08, party 5, error 0.1242
# Collab epoch 08, party 6, error 0.1256
# Collab epoch 08, party 7, error 0.1175
# Collab epoch 08, party 8, error 0.1153
# Collab epoch 08, party 9, error 0.1195
# Collab epoch 08, party 10, error 0.1239
# Collab epoch 08, party 11, error 0.1187
# Collab epoch 08, party 12, error 0.1220
# Collab epoch 08, party 13, error 0.1273
# Collab epoch 08, party 14, error 0.1126
# Collab epoch 08, party 15, error 0.1229
# Collab epoch 08, party 16, error 0.1206
# Collab epoch 08, party 17, error 0.1184
# Collab epoch 08, party 18, error 0.1125
# Collab epoch 08, party 19, error 0.1268
# Collab epoch 08, party 20, error 0.1259
# Collab epoch 08, party 21, error 0.1457
# Collab epoch 08, party 22, error 0.1200
# Collab epoch 08, party 23, error 0.1272
# Collab epoch 08, party 24, error 0.1221
# Collab epoch 08, party 25, error 0.1244
# Collab epoch 08, party 26, error 0.1220
# Collab epoch 08, party 27, error 0.1194
# Collab epoch 09, party 0, error 0.8993
# Collab epoch 09, party 1, error 0.8993
# Collab epoch 09, party 2, error 0.8993
# Collab epoch 09, party 3, error 0.8993
# Collab epoch 09, party 4, error 0.8993
# Collab epoch 09, party 5, error 0.1248
# Collab epoch 09, party 6, error 0.1287
# Collab epoch 09, party 7, error 0.1183
# Collab epoch 09, party 8, error 0.1181
# Collab epoch 09, party 9, error 0.1206
# Collab epoch 09, party 10, error 0.1260
# Collab epoch 09, party 11, error 0.1204
# Collab epoch 09, party 12, error 0.1252
# Collab epoch 09, party 13, error 0.1296
# Collab epoch 09, party 14, error 0.1147
# Collab epoch 09, party 15, error 0.1254
# Collab epoch 09, party 16, error 0.1228
# Collab epoch 09, party 17, error 0.1215
# Collab epoch 09, party 18, error 0.1159
# Collab epoch 09, party 19, error 0.1294
# Collab epoch 09, party 20, error 0.1286
# Collab epoch 09, party 21, error 0.1488
# Collab epoch 09, party 22, error 0.1250
# Collab epoch 09, party 23, error 0.1310
# Collab epoch 09, party 24, error 0.1231
# Collab epoch 09, party 25, error 0.1274
# Collab epoch 09, party 26, error 0.1237
# Collab epoch 09, party 27, error 0.1219
# Collab epoch 10, party 0, error 0.8993
# Collab epoch 10, party 1, error 0.8993
# Collab epoch 10, party 2, error 0.8993
# Collab epoch 10, party 3, error 0.8993
# Collab epoch 10, party 4, error 0.8993
# Collab epoch 10, party 5, error 0.1264
# Collab epoch 10, party 6, error 0.1318
# Collab epoch 10, party 7, error 0.1205
# Collab epoch 10, party 8, error 0.1215
# Collab epoch 10, party 9, error 0.1237
# Collab epoch 10, party 10, error 0.1304
# Collab epoch 10, party 11, error 0.1226
# Collab epoch 10, party 12, error 0.1292
# Collab epoch 10, party 13, error 0.1322
# Collab epoch 10, party 14, error 0.1165
# Collab epoch 10, party 15, error 0.1283
# Collab epoch 10, party 16, error 0.1262
# Collab epoch 10, party 17, error 0.1270
# Collab epoch 10, party 18, error 0.1198
# Collab epoch 10, party 19, error 0.1313
# Collab epoch 10, party 20, error 0.1317
# Collab epoch 10, party 21, error 0.1522
# Collab epoch 10, party 22, error 0.1277
# Collab epoch 10, party 23, error 0.1353
# Collab epoch 10, party 24, error 0.1259
# Collab epoch 10, party 25, error 0.1327
# Collab epoch 10, party 26, error 0.1283
# Collab epoch 10, party 27, error 0.1267
# Collab epoch 11, party 0, error 0.8992
# Collab epoch 11, party 1, error 0.8992
# Collab epoch 11, party 2, error 0.8992
# Collab epoch 11, party 3, error 0.8992
# Collab epoch 11, party 4, error 0.8992
# Collab epoch 11, party 5, error 0.1289
# Collab epoch 11, party 6, error 0.1377
# Collab epoch 11, party 7, error 0.1229
# Collab epoch 11, party 8, error 0.1253
# Collab epoch 11, party 9, error 0.1268
# Collab epoch 11, party 10, error 0.1332
# Collab epoch 11, party 11, error 0.1255
# Collab epoch 11, party 12, error 0.1330
# Collab epoch 11, party 13, error 0.1345
# Collab epoch 11, party 14, error 0.1187
# Collab epoch 11, party 15, error 0.1298
# Collab epoch 11, party 16, error 0.1299
# Collab epoch 11, party 17, error 0.1302
# Collab epoch 11, party 18, error 0.1224
# Collab epoch 11, party 19, error 0.1351
# Collab epoch 11, party 20, error 0.1345
# Collab epoch 11, party 21, error 0.1555
# Collab epoch 11, party 22, error 0.1307
# Collab epoch 11, party 23, error 0.1392
# Collab epoch 11, party 24, error 0.1282
# Collab epoch 11, party 25, error 0.1350
# Collab epoch 11, party 26, error 0.1306
# Collab epoch 11, party 27, error 0.1311
# Collab epoch 12, party 0, error 0.8992
# Collab epoch 12, party 1, error 0.8992
# Collab epoch 12, party 2, error 0.8992
# Collab epoch 12, party 3, error 0.8992
# Collab epoch 12, party 4, error 0.8992
# Collab epoch 12, party 5, error 0.1317
# Collab epoch 12, party 6, error 0.1403
# Collab epoch 12, party 7, error 0.1250
# Collab epoch 12, party 8, error 0.1271
# Collab epoch 12, party 9, error 0.1301
# Collab epoch 12, party 10, error 0.1360
# Collab epoch 12, party 11, error 0.1282
# Collab epoch 12, party 12, error 0.1359
# Collab epoch 12, party 13, error 0.1373
# Collab epoch 12, party 14, error 0.1217
# Collab epoch 12, party 15, error 0.1336
# Collab epoch 12, party 16, error 0.1329
# Collab epoch 12, party 17, error 0.1343
# Collab epoch 12, party 18, error 0.1280
# Collab epoch 12, party 19, error 0.1384
# Collab epoch 12, party 20, error 0.1370
# Collab epoch 12, party 21, error 0.1594
# Collab epoch 12, party 22, error 0.1338
# Collab epoch 12, party 23, error 0.1436
# Collab epoch 12, party 24, error 0.1312
# Collab epoch 12, party 25, error 0.1400
# Collab epoch 12, party 26, error 0.1317
# Collab epoch 12, party 27, error 0.1347
# Collab epoch 13, party 0, error 0.8993
# Collab epoch 13, party 1, error 0.8993
# Collab epoch 13, party 2, error 0.8993
# Collab epoch 13, party 3, error 0.8993
# Collab epoch 13, party 4, error 0.8993
# Collab epoch 13, party 5, error 0.1341
# Collab epoch 13, party 6, error 0.1446
# Collab epoch 13, party 7, error 0.1272
# Collab epoch 13, party 8, error 0.1288
# Collab epoch 13, party 9, error 0.1345
# Collab epoch 13, party 10, error 0.1402
# Collab epoch 13, party 11, error 0.1318
# Collab epoch 13, party 12, error 0.1394
# Collab epoch 13, party 13, error 0.1392
# Collab epoch 13, party 14, error 0.1239
# Collab epoch 13, party 15, error 0.1364
# Collab epoch 13, party 16, error 0.1372
# Collab epoch 13, party 17, error 0.1393
# Collab epoch 13, party 18, error 0.1347
# Collab epoch 13, party 19, error 0.1429
# Collab epoch 13, party 20, error 0.1406
# Collab epoch 13, party 21, error 0.1649
# Collab epoch 13, party 22, error 0.1367
# Collab epoch 13, party 23, error 0.1473
# Collab epoch 13, party 24, error 0.1339
# Collab epoch 13, party 25, error 0.1449
# Collab epoch 13, party 26, error 0.1355
# Collab epoch 13, party 27, error 0.1384
# Collab epoch 14, party 0, error 0.8992
# Collab epoch 14, party 1, error 0.8992
# Collab epoch 14, party 2, error 0.8992
# Collab epoch 14, party 3, error 0.8992
# Collab epoch 14, party 4, error 0.8992
# Collab epoch 14, party 5, error 0.1370
# Collab epoch 14, party 6, error 0.1475
# Collab epoch 14, party 7, error 0.1295
# Collab epoch 14, party 8, error 0.1309
# Collab epoch 14, party 9, error 0.1381
# Collab epoch 14, party 10, error 0.1442
# Collab epoch 14, party 11, error 0.1339
# Collab epoch 14, party 12, error 0.1417
# Collab epoch 14, party 13, error 0.1428
# Collab epoch 14, party 14, error 0.1279
# Collab epoch 14, party 15, error 0.1395
# Collab epoch 14, party 16, error 0.1420
# Collab epoch 14, party 17, error 0.1440
# Collab epoch 14, party 18, error 0.1396
# Collab epoch 14, party 19, error 0.1461
# Collab epoch 14, party 20, error 0.1444
# Collab epoch 14, party 21, error 0.1690
# Collab epoch 14, party 22, error 0.1404
# Collab epoch 14, party 23, error 0.1516
# Collab epoch 14, party 24, error 0.1365
# Collab epoch 14, party 25, error 0.1502
# Collab epoch 14, party 26, error 0.1386
# Collab epoch 14, party 27, error 0.1437
# Collab epoch 15, party 0, error 0.8992
# Collab epoch 15, party 1, error 0.8992
# Collab epoch 15, party 2, error 0.8992
# Collab epoch 15, party 3, error 0.8992
# Collab epoch 15, party 4, error 0.8992
# Collab epoch 15, party 5, error 0.1396
# Collab epoch 15, party 6, error 0.1512
# Collab epoch 15, party 7, error 0.1331
# Collab epoch 15, party 8, error 0.1347
# Collab epoch 15, party 9, error 0.1404
# Collab epoch 15, party 10, error 0.1481
# Collab epoch 15, party 11, error 0.1370
# Collab epoch 15, party 12, error 0.1465
# Collab epoch 15, party 13, error 0.1443
# Collab epoch 15, party 14, error 0.1326
# Collab epoch 15, party 15, error 0.1427
# Collab epoch 15, party 16, error 0.1466
# Collab epoch 15, party 17, error 0.1482
# Collab epoch 15, party 18, error 0.1441
# Collab epoch 15, party 19, error 0.1500
# Collab epoch 15, party 20, error 0.1487
# Collab epoch 15, party 21, error 0.1733
# Collab epoch 15, party 22, error 0.1427
# Collab epoch 15, party 23, error 0.1546
# Collab epoch 15, party 24, error 0.1388
# Collab epoch 15, party 25, error 0.1548
# Collab epoch 15, party 26, error 0.1414
# Collab epoch 15, party 27, error 0.1487
# Collab epoch 16, party 0, error 0.8992
# Collab epoch 16, party 1, error 0.8992
# Collab epoch 16, party 2, error 0.8992
# Collab epoch 16, party 3, error 0.8992
# Collab epoch 16, party 4, error 0.8992
# Collab epoch 16, party 5, error 0.1425
# Collab epoch 16, party 6, error 0.1551
# Collab epoch 16, party 7, error 0.1370
# Collab epoch 16, party 8, error 0.1379
# Collab epoch 16, party 9, error 0.1436
# Collab epoch 16, party 10, error 0.1531
# Collab epoch 16, party 11, error 0.1398
# Collab epoch 16, party 12, error 0.1495
# Collab epoch 16, party 13, error 0.1456
# Collab epoch 16, party 14, error 0.1373
# Collab epoch 16, party 15, error 0.1481
# Collab epoch 16, party 16, error 0.1495
# Collab epoch 16, party 17, error 0.1516
# Collab epoch 16, party 18, error 0.1485
# Collab epoch 16, party 19, error 0.1526
# Collab epoch 16, party 20, error 0.1525
# Collab epoch 16, party 21, error 0.1779
# Collab epoch 16, party 22, error 0.1448
# Collab epoch 16, party 23, error 0.1590
# Collab epoch 16, party 24, error 0.1411
# Collab epoch 16, party 25, error 0.1579
# Collab epoch 16, party 26, error 0.1454
# Collab epoch 16, party 27, error 0.1534
# Collab epoch 17, party 0, error 0.8992
# Collab epoch 17, party 1, error 0.8992
# Collab epoch 17, party 2, error 0.8992
# Collab epoch 17, party 3, error 0.8992
# Collab epoch 17, party 4, error 0.8992
# Collab epoch 17, party 5, error 0.1451
# Collab epoch 17, party 6, error 0.1605
# Collab epoch 17, party 7, error 0.1403
# Collab epoch 17, party 8, error 0.1410
# Collab epoch 17, party 9, error 0.1469
# Collab epoch 17, party 10, error 0.1578
# Collab epoch 17, party 11, error 0.1424
# Collab epoch 17, party 12, error 0.1544
# Collab epoch 17, party 13, error 0.1480
# Collab epoch 17, party 14, error 0.1414
# Collab epoch 17, party 15, error 0.1508
# Collab epoch 17, party 16, error 0.1545
# Collab epoch 17, party 17, error 0.1538
# Collab epoch 17, party 18, error 0.1534
# Collab epoch 17, party 19, error 0.1549
# Collab epoch 17, party 20, error 0.1566
# Collab epoch 17, party 21, error 0.1824
# Collab epoch 17, party 22, error 0.1480
# Collab epoch 17, party 23, error 0.1624
# Collab epoch 17, party 24, error 0.1443
# Collab epoch 17, party 25, error 0.1607
# Collab epoch 17, party 26, error 0.1492
# Collab epoch 17, party 27, error 0.1571
# Collab epoch 18, party 0, error 0.8991
# Collab epoch 18, party 1, error 0.8991
# Collab epoch 18, party 2, error 0.8991
# Collab epoch 18, party 3, error 0.8991
# Collab epoch 18, party 4, error 0.8991
# Collab epoch 18, party 5, error 0.1474
# Collab epoch 18, party 6, error 0.1643
# Collab epoch 18, party 7, error 0.1453
# Collab epoch 18, party 8, error 0.1455
# Collab epoch 18, party 9, error 0.1503
# Collab epoch 18, party 10, error 0.1620
# Collab epoch 18, party 11, error 0.1465
# Collab epoch 18, party 12, error 0.1584
# Collab epoch 18, party 13, error 0.1515
# Collab epoch 18, party 14, error 0.1461
# Collab epoch 18, party 15, error 0.1528
# Collab epoch 18, party 16, error 0.1597
# Collab epoch 18, party 17, error 0.1573
# Collab epoch 18, party 18, error 0.1581
# Collab epoch 18, party 19, error 0.1583
# Collab epoch 18, party 20, error 0.1598
# Collab epoch 18, party 21, error 0.1872
# Collab epoch 18, party 22, error 0.1515
# Collab epoch 18, party 23, error 0.1653
# Collab epoch 18, party 24, error 0.1467
# Collab epoch 18, party 25, error 0.1647
# Collab epoch 18, party 26, error 0.1530
# Collab epoch 18, party 27, error 0.1594
# Collab epoch 19, party 0, error 0.8992
# Collab epoch 19, party 1, error 0.8992
# Collab epoch 19, party 2, error 0.8992
# Collab epoch 19, party 3, error 0.8992
# Collab epoch 19, party 4, error 0.8992
# Collab epoch 19, party 5, error 0.1497
# Collab epoch 19, party 6, error 0.1693
# Collab epoch 19, party 7, error 0.1497
# Collab epoch 19, party 8, error 0.1489
# Collab epoch 19, party 9, error 0.1547
# Collab epoch 19, party 10, error 0.1660
# Collab epoch 19, party 11, error 0.1509
# Collab epoch 19, party 12, error 0.1624
# Collab epoch 19, party 13, error 0.1540
# Collab epoch 19, party 14, error 0.1499
# Collab epoch 19, party 15, error 0.1556
# Collab epoch 19, party 16, error 0.1646
# Collab epoch 19, party 17, error 0.1602
# Collab epoch 19, party 18, error 0.1610
# Collab epoch 19, party 19, error 0.1609
# Collab epoch 19, party 20, error 0.1639
# Collab epoch 19, party 21, error 0.1900
# Collab epoch 19, party 22, error 0.1552
# Collab epoch 19, party 23, error 0.1677
# Collab epoch 19, party 24, error 0.1487
# Collab epoch 19, party 25, error 0.1666
# Collab epoch 19, party 26, error 0.1553
# Collab epoch 19, party 27, error 0.1628
# Collab epoch 20, party 0, error 0.8992
# Collab epoch 20, party 1, error 0.8992
# Collab epoch 20, party 2, error 0.8992
# Collab epoch 20, party 3, error 0.8992
# Collab epoch 20, party 4, error 0.8992
# Collab epoch 20, party 5, error 0.1525
# Collab epoch 20, party 6, error 0.1737
# Collab epoch 20, party 7, error 0.1549
# Collab epoch 20, party 8, error 0.1526
# Collab epoch 20, party 9, error 0.1562
# Collab epoch 20, party 10, error 0.1696
# Collab epoch 20, party 11, error 0.1534
# Collab epoch 20, party 12, error 0.1654
# Collab epoch 20, party 13, error 0.1564
# Collab epoch 20, party 14, error 0.1547
# Collab epoch 20, party 15, error 0.1587
# Collab epoch 20, party 16, error 0.1681
# Collab epoch 20, party 17, error 0.1628
# Collab epoch 20, party 18, error 0.1635
# Collab epoch 20, party 19, error 0.1644
# Collab epoch 20, party 20, error 0.1674
# Collab epoch 20, party 21, error 0.1947
# Collab epoch 20, party 22, error 0.1575
# Collab epoch 20, party 23, error 0.1716
# Collab epoch 20, party 24, error 0.1506
# Collab epoch 20, party 25, error 0.1707
# Collab epoch 20, party 26, error 0.1591
# Collab epoch 20, party 27, error 0.1662
# Collab epoch 21, party 0, error 0.8991
# Collab epoch 21, party 1, error 0.8991
# Collab epoch 21, party 2, error 0.8991
# Collab epoch 21, party 3, error 0.8991
# Collab epoch 21, party 4, error 0.8991
# Collab epoch 21, party 5, error 0.1540
# Collab epoch 21, party 6, error 0.1775
# Collab epoch 21, party 7, error 0.1583
# Collab epoch 21, party 8, error 0.1566
# Collab epoch 21, party 9, error 0.1586
# Collab epoch 21, party 10, error 0.1740
# Collab epoch 21, party 11, error 0.1569
# Collab epoch 21, party 12, error 0.1688
# Collab epoch 21, party 13, error 0.1599
# Collab epoch 21, party 14, error 0.1589
# Collab epoch 21, party 15, error 0.1618
# Collab epoch 21, party 16, error 0.1709
# Collab epoch 21, party 17, error 0.1648
# Collab epoch 21, party 18, error 0.1672
# Collab epoch 21, party 19, error 0.1661
# Collab epoch 21, party 20, error 0.1707
# Collab epoch 21, party 21, error 0.1969
# Collab epoch 21, party 22, error 0.1599
# Collab epoch 21, party 23, error 0.1735
# Collab epoch 21, party 24, error 0.1553
# Collab epoch 21, party 25, error 0.1744
# Collab epoch 21, party 26, error 0.1631
# Collab epoch 21, party 27, error 0.1695
# Collab epoch 22, party 0, error 0.8991
# Collab epoch 22, party 1, error 0.8991
# Collab epoch 22, party 2, error 0.8991
# Collab epoch 22, party 3, error 0.8991
# Collab epoch 22, party 4, error 0.8991
# Collab epoch 22, party 5, error 0.1563
# Collab epoch 22, party 6, error 0.1812
# Collab epoch 22, party 7, error 0.1615
# Collab epoch 22, party 8, error 0.1596
# Collab epoch 22, party 9, error 0.1616
# Collab epoch 22, party 10, error 0.1779
# Collab epoch 22, party 11, error 0.1603
# Collab epoch 22, party 12, error 0.1712
# Collab epoch 22, party 13, error 0.1626
# Collab epoch 22, party 14, error 0.1620
# Collab epoch 22, party 15, error 0.1639
# Collab epoch 22, party 16, error 0.1741
# Collab epoch 22, party 17, error 0.1681
# Collab epoch 22, party 18, error 0.1711
# Collab epoch 22, party 19, error 0.1685
# Collab epoch 22, party 20, error 0.1751
# Collab epoch 22, party 21, error 0.1991
# Collab epoch 22, party 22, error 0.1608
# Collab epoch 22, party 23, error 0.1773
# Collab epoch 22, party 24, error 0.1578
# Collab epoch 22, party 25, error 0.1778
# Collab epoch 22, party 26, error 0.1670
# Collab epoch 22, party 27, error 0.1730
# Collab epoch 23, party 0, error 0.8992
# Collab epoch 23, party 1, error 0.8992
# Collab epoch 23, party 2, error 0.8992
# Collab epoch 23, party 3, error 0.8992
# Collab epoch 23, party 4, error 0.8992
# Collab epoch 23, party 5, error 0.1581
# Collab epoch 23, party 6, error 0.1846
# Collab epoch 23, party 7, error 0.1634
# Collab epoch 23, party 8, error 0.1620
# Collab epoch 23, party 9, error 0.1643
# Collab epoch 23, party 10, error 0.1814
# Collab epoch 23, party 11, error 0.1625
# Collab epoch 23, party 12, error 0.1745
# Collab epoch 23, party 13, error 0.1651
# Collab epoch 23, party 14, error 0.1663
# Collab epoch 23, party 15, error 0.1658
# Collab epoch 23, party 16, error 0.1772
# Collab epoch 23, party 17, error 0.1708
# Collab epoch 23, party 18, error 0.1734
# Collab epoch 23, party 19, error 0.1714
# Collab epoch 23, party 20, error 0.1786
# Collab epoch 23, party 21, error 0.2031
# Collab epoch 23, party 22, error 0.1625
# Collab epoch 23, party 23, error 0.1791
# Collab epoch 23, party 24, error 0.1601
# Collab epoch 23, party 25, error 0.1806
# Collab epoch 23, party 26, error 0.1715
# Collab epoch 23, party 27, error 0.1745
# Collab epoch 24, party 0, error 0.8992
# Collab epoch 24, party 1, error 0.8992
# Collab epoch 24, party 2, error 0.8992
# Collab epoch 24, party 3, error 0.8992
# Collab epoch 24, party 4, error 0.8992
# Collab epoch 24, party 5, error 0.1608
# Collab epoch 24, party 6, error 0.1875
# Collab epoch 24, party 7, error 0.1674
# Collab epoch 24, party 8, error 0.1633
# Collab epoch 24, party 9, error 0.1663
# Collab epoch 24, party 10, error 0.1843
# Collab epoch 24, party 11, error 0.1662
# Collab epoch 24, party 12, error 0.1755
# Collab epoch 24, party 13, error 0.1667
# Collab epoch 24, party 14, error 0.1706
# Collab epoch 24, party 15, error 0.1692
# Collab epoch 24, party 16, error 0.1799
# Collab epoch 24, party 17, error 0.1735
# Collab epoch 24, party 18, error 0.1745
# Collab epoch 24, party 19, error 0.1735
# Collab epoch 24, party 20, error 0.1820
# Collab epoch 24, party 21, error 0.2053
# Collab epoch 24, party 22, error 0.1631
# Collab epoch 24, party 23, error 0.1810
# Collab epoch 24, party 24, error 0.1640
# Collab epoch 24, party 25, error 0.1828
# Collab epoch 24, party 26, error 0.1756
# Collab epoch 24, party 27, error 0.1753
# Collab epoch 25, party 0, error 0.8992
# Collab epoch 25, party 1, error 0.8992
# Collab epoch 25, party 2, error 0.8992
# Collab epoch 25, party 3, error 0.8992
# Collab epoch 25, party 4, error 0.8992
# Collab epoch 25, party 5, error 0.1629
# Collab epoch 25, party 6, error 0.1915
# Collab epoch 25, party 7, error 0.1702
# Collab epoch 25, party 8, error 0.1666
# Collab epoch 25, party 9, error 0.1685
# Collab epoch 25, party 10, error 0.1873
# Collab epoch 25, party 11, error 0.1687
# Collab epoch 25, party 12, error 0.1782
# Collab epoch 25, party 13, error 0.1697
# Collab epoch 25, party 14, error 0.1740
# Collab epoch 25, party 15, error 0.1722
# Collab epoch 25, party 16, error 0.1822
# Collab epoch 25, party 17, error 0.1761
# Collab epoch 25, party 18, error 0.1772
# Collab epoch 25, party 19, error 0.1755
# Collab epoch 25, party 20, error 0.1847
# Collab epoch 25, party 21, error 0.2074
# Collab epoch 25, party 22, error 0.1645
# Collab epoch 25, party 23, error 0.1834
# Collab epoch 25, party 24, error 0.1660
# Collab epoch 25, party 25, error 0.1846
# Collab epoch 25, party 26, error 0.1786
# Collab epoch 25, party 27, error 0.1759
# Collab epoch 26, party 0, error 0.8993
# Collab epoch 26, party 1, error 0.8993
# Collab epoch 26, party 2, error 0.8993
# Collab epoch 26, party 3, error 0.8993
# Collab epoch 26, party 4, error 0.8993
# Collab epoch 26, party 5, error 0.1642
# Collab epoch 26, party 6, error 0.1928
# Collab epoch 26, party 7, error 0.1739
# Collab epoch 26, party 8, error 0.1697
# Collab epoch 26, party 9, error 0.1703
# Collab epoch 26, party 10, error 0.1913
# Collab epoch 26, party 11, error 0.1700
# Collab epoch 26, party 12, error 0.1807
# Collab epoch 26, party 13, error 0.1705
# Collab epoch 26, party 14, error 0.1788
# Collab epoch 26, party 15, error 0.1751
# Collab epoch 26, party 16, error 0.1839
# Collab epoch 26, party 17, error 0.1785
# Collab epoch 26, party 18, error 0.1791
# Collab epoch 26, party 19, error 0.1779
# Collab epoch 26, party 20, error 0.1864
# Collab epoch 26, party 21, error 0.2096
# Collab epoch 26, party 22, error 0.1651
# Collab epoch 26, party 23, error 0.1856
# Collab epoch 26, party 24, error 0.1688
# Collab epoch 26, party 25, error 0.1870
# Collab epoch 26, party 26, error 0.1807
# Collab epoch 26, party 27, error 0.1788
# Collab epoch 27, party 0, error 0.8993
# Collab epoch 27, party 1, error 0.8993
# Collab epoch 27, party 2, error 0.8993
# Collab epoch 27, party 3, error 0.8993
# Collab epoch 27, party 4, error 0.8993
# Collab epoch 27, party 5, error 0.1677
# Collab epoch 27, party 6, error 0.1953
# Collab epoch 27, party 7, error 0.1766
# Collab epoch 27, party 8, error 0.1714
# Collab epoch 27, party 9, error 0.1711
# Collab epoch 27, party 10, error 0.1940
# Collab epoch 27, party 11, error 0.1734
# Collab epoch 27, party 12, error 0.1841
# Collab epoch 27, party 13, error 0.1727
# Collab epoch 27, party 14, error 0.1821
# Collab epoch 27, party 15, error 0.1778
# Collab epoch 27, party 16, error 0.1863
# Collab epoch 27, party 17, error 0.1799
# Collab epoch 27, party 18, error 0.1800
# Collab epoch 27, party 19, error 0.1797
# Collab epoch 27, party 20, error 0.1902
# Collab epoch 27, party 21, error 0.2117
# Collab epoch 27, party 22, error 0.1670
# Collab epoch 27, party 23, error 0.1875
# Collab epoch 27, party 24, error 0.1710
# Collab epoch 27, party 25, error 0.1887
# Collab epoch 27, party 26, error 0.1820
# Collab epoch 27, party 27, error 0.1800
# Collab epoch 28, party 0, error 0.8993
# Collab epoch 28, party 1, error 0.8993
# Collab epoch 28, party 2, error 0.8993
# Collab epoch 28, party 3, error 0.8993
# Collab epoch 28, party 4, error 0.8993
# Collab epoch 28, party 5, error 0.1685
# Collab epoch 28, party 6, error 0.1978
# Collab epoch 28, party 7, error 0.1793
# Collab epoch 28, party 8, error 0.1734
# Collab epoch 28, party 9, error 0.1741
# Collab epoch 28, party 10, error 0.1969
# Collab epoch 28, party 11, error 0.1763
# Collab epoch 28, party 12, error 0.1866
# Collab epoch 28, party 13, error 0.1742
# Collab epoch 28, party 14, error 0.1848
# Collab epoch 28, party 15, error 0.1802
# Collab epoch 28, party 16, error 0.1874
# Collab epoch 28, party 17, error 0.1812
# Collab epoch 28, party 18, error 0.1816
# Collab epoch 28, party 19, error 0.1811
# Collab epoch 28, party 20, error 0.1932
# Collab epoch 28, party 21, error 0.2126
# Collab epoch 28, party 22, error 0.1679
# Collab epoch 28, party 23, error 0.1896
# Collab epoch 28, party 24, error 0.1742
# Collab epoch 28, party 25, error 0.1910
# Collab epoch 28, party 26, error 0.1841
# Collab epoch 28, party 27, error 0.1811
# Collab epoch 29, party 0, error 0.8993
# Collab epoch 29, party 1, error 0.8993
# Collab epoch 29, party 2, error 0.8993
# Collab epoch 29, party 3, error 0.8993
# Collab epoch 29, party 4, error 0.8993
# Collab epoch 29, party 5, error 0.1695
# Collab epoch 29, party 6, error 0.1993
# Collab epoch 29, party 7, error 0.1804
# Collab epoch 29, party 8, error 0.1751
# Collab epoch 29, party 9, error 0.1762
# Collab epoch 29, party 10, error 0.1985
# Collab epoch 29, party 11, error 0.1776
# Collab epoch 29, party 12, error 0.1888
# Collab epoch 29, party 13, error 0.1755
# Collab epoch 29, party 14, error 0.1875
# Collab epoch 29, party 15, error 0.1820
# Collab epoch 29, party 16, error 0.1902
# Collab epoch 29, party 17, error 0.1826
# Collab epoch 29, party 18, error 0.1831
# Collab epoch 29, party 19, error 0.1829
# Collab epoch 29, party 20, error 0.1952
# Collab epoch 29, party 21, error 0.2140
# Collab epoch 29, party 22, error 0.1698
# Collab epoch 29, party 23, error 0.1918
# Collab epoch 29, party 24, error 0.1763
# Collab epoch 29, party 25, error 0.1925
# Collab epoch 29, party 26, error 0.1859
# Collab epoch 29, party 27, error 0.1826
# Collab epoch 30, party 0, error 0.8993
# Collab epoch 30, party 1, error 0.8993
# Collab epoch 30, party 2, error 0.8993
# Collab epoch 30, party 3, error 0.8993
# Collab epoch 30, party 4, error 0.8993
# Collab epoch 30, party 5, error 0.1717
# Collab epoch 30, party 6, error 0.2018
# Collab epoch 30, party 7, error 0.1804
# Collab epoch 30, party 8, error 0.1771
# Collab epoch 30, party 9, error 0.1779
# Collab epoch 30, party 10, error 0.1999
# Collab epoch 30, party 11, error 0.1795
# Collab epoch 30, party 12, error 0.1903
# Collab epoch 30, party 13, error 0.1768
# Collab epoch 30, party 14, error 0.1898
# Collab epoch 30, party 15, error 0.1831
# Collab epoch 30, party 16, error 0.1918
# Collab epoch 30, party 17, error 0.1848
# Collab epoch 30, party 18, error 0.1839
# Collab epoch 30, party 19, error 0.1832
# Collab epoch 30, party 20, error 0.1961
# Collab epoch 30, party 21, error 0.2151
# Collab epoch 30, party 22, error 0.1711
# Collab epoch 30, party 23, error 0.1936
# Collab epoch 30, party 24, error 0.1773
# Collab epoch 30, party 25, error 0.1921
# Collab epoch 30, party 26, error 0.1874
# Collab epoch 30, party 27, error 0.1834
# Collab epoch 31, party 0, error 0.8993
# Collab epoch 31, party 1, error 0.8993
# Collab epoch 31, party 2, error 0.8993
# Collab epoch 31, party 3, error 0.8993
# Collab epoch 31, party 4, error 0.8993
# Collab epoch 31, party 5, error 0.1721
# Collab epoch 31, party 6, error 0.2047
# Collab epoch 31, party 7, error 0.1816
# Collab epoch 31, party 8, error 0.1787
# Collab epoch 31, party 9, error 0.1787
# Collab epoch 31, party 10, error 0.2017
# Collab epoch 31, party 11, error 0.1800
# Collab epoch 31, party 12, error 0.1914
# Collab epoch 31, party 13, error 0.1776
# Collab epoch 31, party 14, error 0.1912
# Collab epoch 31, party 15, error 0.1842
# Collab epoch 31, party 16, error 0.1926
# Collab epoch 31, party 17, error 0.1847
# Collab epoch 31, party 18, error 0.1845
# Collab epoch 31, party 19, error 0.1865
# Collab epoch 31, party 20, error 0.1976
# Collab epoch 31, party 21, error 0.2160
# Collab epoch 31, party 22, error 0.1719
# Collab epoch 31, party 23, error 0.1939
# Collab epoch 31, party 24, error 0.1789
# Collab epoch 31, party 25, error 0.1926
# Collab epoch 31, party 26, error 0.1880
# Collab epoch 31, party 27, error 0.1847
# Collab epoch 32, party 0, error 0.8993
# Collab epoch 32, party 1, error 0.8993
# Collab epoch 32, party 2, error 0.8993
# Collab epoch 32, party 3, error 0.8993
# Collab epoch 32, party 4, error 0.8993
# Collab epoch 32, party 5, error 0.1724
# Collab epoch 32, party 6, error 0.2075
# Collab epoch 32, party 7, error 0.1822
# Collab epoch 32, party 8, error 0.1804
# Collab epoch 32, party 9, error 0.1804
# Collab epoch 32, party 10, error 0.2028
# Collab epoch 32, party 11, error 0.1808
# Collab epoch 32, party 12, error 0.1926
# Collab epoch 32, party 13, error 0.1783
# Collab epoch 32, party 14, error 0.1929
# Collab epoch 32, party 15, error 0.1847
# Collab epoch 32, party 16, error 0.1943
# Collab epoch 32, party 17, error 0.1854
# Collab epoch 32, party 18, error 0.1851
# Collab epoch 32, party 19, error 0.1878
# Collab epoch 32, party 20, error 0.1993
# Collab epoch 32, party 21, error 0.2167
# Collab epoch 32, party 22, error 0.1719
# Collab epoch 32, party 23, error 0.1959
# Collab epoch 32, party 24, error 0.1793
# Collab epoch 32, party 25, error 0.1945
# Collab epoch 32, party 26, error 0.1910
# Collab epoch 32, party 27, error 0.1861
# Collab epoch 33, party 0, error 0.8993
# Collab epoch 33, party 1, error 0.8993
# Collab epoch 33, party 2, error 0.8993
# Collab epoch 33, party 3, error 0.8993
# Collab epoch 33, party 4, error 0.8993
# Collab epoch 33, party 5, error 0.1739
# Collab epoch 33, party 6, error 0.2089
# Collab epoch 33, party 7, error 0.1818
# Collab epoch 33, party 8, error 0.1813
# Collab epoch 33, party 9, error 0.1808
# Collab epoch 33, party 10, error 0.2034
# Collab epoch 33, party 11, error 0.1815
# Collab epoch 33, party 12, error 0.1931
# Collab epoch 33, party 13, error 0.1792
# Collab epoch 33, party 14, error 0.1954
# Collab epoch 33, party 15, error 0.1855
# Collab epoch 33, party 16, error 0.1950
# Collab epoch 33, party 17, error 0.1857
# Collab epoch 33, party 18, error 0.1857
# Collab epoch 33, party 19, error 0.1887
# Collab epoch 33, party 20, error 0.2003
# Collab epoch 33, party 21, error 0.2162
# Collab epoch 33, party 22, error 0.1731
# Collab epoch 33, party 23, error 0.1971
# Collab epoch 33, party 24, error 0.1823
# Collab epoch 33, party 25, error 0.1955
# Collab epoch 33, party 26, error 0.1919
# Collab epoch 33, party 27, error 0.1869
# Collab epoch 34, party 0, error 0.8993
# Collab epoch 34, party 1, error 0.8993
# Collab epoch 34, party 2, error 0.8993
# Collab epoch 34, party 3, error 0.8993
# Collab epoch 34, party 4, error 0.8993
# Collab epoch 34, party 5, error 0.1749
# Collab epoch 34, party 6, error 0.2098
# Collab epoch 34, party 7, error 0.1833
# Collab epoch 34, party 8, error 0.1824
# Collab epoch 34, party 9, error 0.1808
# Collab epoch 34, party 10, error 0.2045
# Collab epoch 34, party 11, error 0.1819
# Collab epoch 34, party 12, error 0.1943
# Collab epoch 34, party 13, error 0.1812
# Collab epoch 34, party 14, error 0.1970
# Collab epoch 34, party 15, error 0.1859
# Collab epoch 34, party 16, error 0.1966
# Collab epoch 34, party 17, error 0.1864
# Collab epoch 34, party 18, error 0.1872
# Collab epoch 34, party 19, error 0.1901
# Collab epoch 34, party 20, error 0.2013
# Collab epoch 34, party 21, error 0.2172
# Collab epoch 34, party 22, error 0.1740
# Collab epoch 34, party 23, error 0.1982
# Collab epoch 34, party 24, error 0.1837
# Collab epoch 34, party 25, error 0.1959
# Collab epoch 34, party 26, error 0.1939
# Collab epoch 34, party 27, error 0.1877
# Collab epoch 35, party 0, error 0.8994
# Collab epoch 35, party 1, error 0.8994
# Collab epoch 35, party 2, error 0.8994
# Collab epoch 35, party 3, error 0.8994
# Collab epoch 35, party 4, error 0.8994
# Collab epoch 35, party 5, error 0.1753
# Collab epoch 35, party 6, error 0.2105
# Collab epoch 35, party 7, error 0.1852
# Collab epoch 35, party 8, error 0.1825
# Collab epoch 35, party 9, error 0.1817
# Collab epoch 35, party 10, error 0.2060
# Collab epoch 35, party 11, error 0.1821
# Collab epoch 35, party 12, error 0.1957
# Collab epoch 35, party 13, error 0.1813
# Collab epoch 35, party 14, error 0.1984
# Collab epoch 35, party 15, error 0.1871
# Collab epoch 35, party 16, error 0.1972
# Collab epoch 35, party 17, error 0.1869
# Collab epoch 35, party 18, error 0.1875
# Collab epoch 35, party 19, error 0.1912
# Collab epoch 35, party 20, error 0.2016
# Collab epoch 35, party 21, error 0.2173
# Collab epoch 35, party 22, error 0.1750
# Collab epoch 35, party 23, error 0.1988
# Collab epoch 35, party 24, error 0.1846
# Collab epoch 35, party 25, error 0.1971
# Collab epoch 35, party 26, error 0.1943
# Collab epoch 35, party 27, error 0.1883
# Collab epoch 36, party 0, error 0.8993
# Collab epoch 36, party 1, error 0.8993
# Collab epoch 36, party 2, error 0.8993
# Collab epoch 36, party 3, error 0.8993
# Collab epoch 36, party 4, error 0.8993
# Collab epoch 36, party 5, error 0.1750
# Collab epoch 36, party 6, error 0.2112
# Collab epoch 36, party 7, error 0.1858
# Collab epoch 36, party 8, error 0.1834
# Collab epoch 36, party 9, error 0.1822
# Collab epoch 36, party 10, error 0.2070
# Collab epoch 36, party 11, error 0.1834
# Collab epoch 36, party 12, error 0.1975
# Collab epoch 36, party 13, error 0.1822
# Collab epoch 36, party 14, error 0.1994
# Collab epoch 36, party 15, error 0.1879
# Collab epoch 36, party 16, error 0.1982
# Collab epoch 36, party 17, error 0.1872
# Collab epoch 36, party 18, error 0.1874
# Collab epoch 36, party 19, error 0.1923
# Collab epoch 36, party 20, error 0.2026
# Collab epoch 36, party 21, error 0.2174
# Collab epoch 36, party 22, error 0.1743
# Collab epoch 36, party 23, error 0.1992
# Collab epoch 36, party 24, error 0.1851
# Collab epoch 36, party 25, error 0.1970
# Collab epoch 36, party 26, error 0.1947
# Collab epoch 36, party 27, error 0.1891
# Collab epoch 37, party 0, error 0.8993
# Collab epoch 37, party 1, error 0.8993
# Collab epoch 37, party 2, error 0.8993
# Collab epoch 37, party 3, error 0.8993
# Collab epoch 37, party 4, error 0.8993
# Collab epoch 37, party 5, error 0.1754
# Collab epoch 37, party 6, error 0.2122
# Collab epoch 37, party 7, error 0.1860
# Collab epoch 37, party 8, error 0.1845
# Collab epoch 37, party 9, error 0.1830
# Collab epoch 37, party 10, error 0.2073
# Collab epoch 37, party 11, error 0.1852
# Collab epoch 37, party 12, error 0.1970
# Collab epoch 37, party 13, error 0.1827
# Collab epoch 37, party 14, error 0.2000
# Collab epoch 37, party 15, error 0.1885
# Collab epoch 37, party 16, error 0.1970
# Collab epoch 37, party 17, error 0.1870
# Collab epoch 37, party 18, error 0.1867
# Collab epoch 37, party 19, error 0.1931
# Collab epoch 37, party 20, error 0.2026
# Collab epoch 37, party 21, error 0.2175
# Collab epoch 37, party 22, error 0.1740
# Collab epoch 37, party 23, error 0.2001
# Collab epoch 37, party 24, error 0.1860
# Collab epoch 37, party 25, error 0.1969
# Collab epoch 37, party 26, error 0.1953
# Collab epoch 37, party 27, error 0.1896
# Collab epoch 38, party 0, error 0.8993
# Collab epoch 38, party 1, error 0.8993
# Collab epoch 38, party 2, error 0.8993
# Collab epoch 38, party 3, error 0.8993
# Collab epoch 38, party 4, error 0.8993
# Collab epoch 38, party 5, error 0.1764
# Collab epoch 38, party 6, error 0.2132
# Collab epoch 38, party 7, error 0.1856
# Collab epoch 38, party 8, error 0.1854
# Collab epoch 38, party 9, error 0.1832
# Collab epoch 38, party 10, error 0.2080
# Collab epoch 38, party 11, error 0.1858
# Collab epoch 38, party 12, error 0.1979
# Collab epoch 38, party 13, error 0.1835
# Collab epoch 38, party 14, error 0.2008
# Collab epoch 38, party 15, error 0.1894
# Collab epoch 38, party 16, error 0.1976
# Collab epoch 38, party 17, error 0.1878
# Collab epoch 38, party 18, error 0.1865
# Collab epoch 38, party 19, error 0.1931
# Collab epoch 38, party 20, error 0.2036
# Collab epoch 38, party 21, error 0.2181
# Collab epoch 38, party 22, error 0.1740
# Collab epoch 38, party 23, error 0.2011
# Collab epoch 38, party 24, error 0.1865
# Collab epoch 38, party 25, error 0.1968
# Collab epoch 38, party 26, error 0.1952
# Collab epoch 38, party 27, error 0.1897
# Collab epoch 39, party 0, error 0.8993
# Collab epoch 39, party 1, error 0.8993
# Collab epoch 39, party 2, error 0.8993
# Collab epoch 39, party 3, error 0.8993
# Collab epoch 39, party 4, error 0.8993
# Collab epoch 39, party 5, error 0.1763
# Collab epoch 39, party 6, error 0.2136
# Collab epoch 39, party 7, error 0.1846
# Collab epoch 39, party 8, error 0.1860
# Collab epoch 39, party 9, error 0.1833
# Collab epoch 39, party 10, error 0.2080
# Collab epoch 39, party 11, error 0.1855
# Collab epoch 39, party 12, error 0.1979
# Collab epoch 39, party 13, error 0.1845
# Collab epoch 39, party 14, error 0.2012
# Collab epoch 39, party 15, error 0.1890
# Collab epoch 39, party 16, error 0.1979
# Collab epoch 39, party 17, error 0.1888
# Collab epoch 39, party 18, error 0.1862
# Collab epoch 39, party 19, error 0.1934
# Collab epoch 39, party 20, error 0.2042
# Collab epoch 39, party 21, error 0.2186
# Collab epoch 39, party 22, error 0.1742
# Collab epoch 39, party 23, error 0.2012
# Collab epoch 39, party 24, error 0.1865
# Collab epoch 39, party 25, error 0.1971
# Collab epoch 39, party 26, error 0.1949
# Collab epoch 39, party 27, error 0.1894
# Collab epoch 40, party 0, error 0.8993
# Collab epoch 40, party 1, error 0.8993
# Collab epoch 40, party 2, error 0.8993
# Collab epoch 40, party 3, error 0.8993
# Collab epoch 40, party 4, error 0.8993
# Collab epoch 40, party 5, error 0.1771
# Collab epoch 40, party 6, error 0.2144
# Collab epoch 40, party 7, error 0.1848
# Collab epoch 40, party 8, error 0.1852
# Collab epoch 40, party 9, error 0.1834
# Collab epoch 40, party 10, error 0.2086
# Collab epoch 40, party 11, error 0.1864
# Collab epoch 40, party 12, error 0.1981
# Collab epoch 40, party 13, error 0.1835
# Collab epoch 40, party 14, error 0.2014
# Collab epoch 40, party 15, error 0.1898
# Collab epoch 40, party 16, error 0.1973
# Collab epoch 40, party 17, error 0.1898
# Collab epoch 40, party 18, error 0.1872
# Collab epoch 40, party 19, error 0.1935
# Collab epoch 40, party 20, error 0.2047
# Collab epoch 40, party 21, error 0.2185
# Collab epoch 40, party 22, error 0.1739
# Collab epoch 40, party 23, error 0.2010
# Collab epoch 40, party 24, error 0.1871
# Collab epoch 40, party 25, error 0.1963
# Collab epoch 40, party 26, error 0.1946
# Collab epoch 40, party 27, error 0.1895
# Collab epoch 41, party 0, error 0.8993
# Collab epoch 41, party 1, error 0.8993
# Collab epoch 41, party 2, error 0.8993
# Collab epoch 41, party 3, error 0.8993
# Collab epoch 41, party 4, error 0.8993
# Collab epoch 41, party 5, error 0.1780
# Collab epoch 41, party 6, error 0.2138
# Collab epoch 41, party 7, error 0.1847
# Collab epoch 41, party 8, error 0.1858
# Collab epoch 41, party 9, error 0.1834
# Collab epoch 41, party 10, error 0.2088
# Collab epoch 41, party 11, error 0.1866
# Collab epoch 41, party 12, error 0.1983
# Collab epoch 41, party 13, error 0.1837
# Collab epoch 41, party 14, error 0.2014
# Collab epoch 41, party 15, error 0.1899
# Collab epoch 41, party 16, error 0.1974
# Collab epoch 41, party 17, error 0.1906
# Collab epoch 41, party 18, error 0.1873
# Collab epoch 41, party 19, error 0.1938
# Collab epoch 41, party 20, error 0.2045
# Collab epoch 41, party 21, error 0.2182
# Collab epoch 41, party 22, error 0.1736
# Collab epoch 41, party 23, error 0.2013
# Collab epoch 41, party 24, error 0.1880
# Collab epoch 41, party 25, error 0.1964
# Collab epoch 41, party 26, error 0.1951
# Collab epoch 41, party 27, error 0.1893
# Collab epoch 42, party 0, error 0.8993
# Collab epoch 42, party 1, error 0.8993
# Collab epoch 42, party 2, error 0.8993
# Collab epoch 42, party 3, error 0.8993
# Collab epoch 42, party 4, error 0.8993
# Collab epoch 42, party 5, error 0.1779
# Collab epoch 42, party 6, error 0.2143
# Collab epoch 42, party 7, error 0.1849
# Collab epoch 42, party 8, error 0.1864
# Collab epoch 42, party 9, error 0.1833
# Collab epoch 42, party 10, error 0.2084
# Collab epoch 42, party 11, error 0.1866
# Collab epoch 42, party 12, error 0.1987
# Collab epoch 42, party 13, error 0.1836
# Collab epoch 42, party 14, error 0.2017
# Collab epoch 42, party 15, error 0.1906
# Collab epoch 42, party 16, error 0.1982
# Collab epoch 42, party 17, error 0.1902
# Collab epoch 42, party 18, error 0.1875
# Collab epoch 42, party 19, error 0.1942
# Collab epoch 42, party 20, error 0.2047
# Collab epoch 42, party 21, error 0.2182
# Collab epoch 42, party 22, error 0.1740
# Collab epoch 42, party 23, error 0.2013
# Collab epoch 42, party 24, error 0.1880
# Collab epoch 42, party 25, error 0.1969
# Collab epoch 42, party 26, error 0.1959
# Collab epoch 42, party 27, error 0.1896
# Collab epoch 43, party 0, error 0.8992
# Collab epoch 43, party 1, error 0.8992
# Collab epoch 43, party 2, error 0.8992
# Collab epoch 43, party 3, error 0.8992
# Collab epoch 43, party 4, error 0.8992
# Collab epoch 43, party 5, error 0.1785
# Collab epoch 43, party 6, error 0.2143
# Collab epoch 43, party 7, error 0.1849
# Collab epoch 43, party 8, error 0.1867
# Collab epoch 43, party 9, error 0.1835
# Collab epoch 43, party 10, error 0.2082
# Collab epoch 43, party 11, error 0.1862
# Collab epoch 43, party 12, error 0.1989
# Collab epoch 43, party 13, error 0.1834
# Collab epoch 43, party 14, error 0.2017
# Collab epoch 43, party 15, error 0.1904
# Collab epoch 43, party 16, error 0.1980
# Collab epoch 43, party 17, error 0.1900
# Collab epoch 43, party 18, error 0.1882
# Collab epoch 43, party 19, error 0.1951
# Collab epoch 43, party 20, error 0.2041
# Collab epoch 43, party 21, error 0.2182
# Collab epoch 43, party 22, error 0.1736
# Collab epoch 43, party 23, error 0.2014
# Collab epoch 43, party 24, error 0.1882
# Collab epoch 43, party 25, error 0.1970
# Collab epoch 43, party 26, error 0.1969
# Collab epoch 43, party 27, error 0.1896
# Collab epoch 44, party 0, error 0.8992
# Collab epoch 44, party 1, error 0.8992
# Collab epoch 44, party 2, error 0.8992
# Collab epoch 44, party 3, error 0.8992
# Collab epoch 44, party 4, error 0.8992
# Collab epoch 44, party 5, error 0.1786
# Collab epoch 44, party 6, error 0.2145
# Collab epoch 44, party 7, error 0.1854
# Collab epoch 44, party 8, error 0.1874
# Collab epoch 44, party 9, error 0.1836
# Collab epoch 44, party 10, error 0.2079
# Collab epoch 44, party 11, error 0.1866
# Collab epoch 44, party 12, error 0.1981
# Collab epoch 44, party 13, error 0.1833
# Collab epoch 44, party 14, error 0.2018
# Collab epoch 44, party 15, error 0.1899
# Collab epoch 44, party 16, error 0.1980
# Collab epoch 44, party 17, error 0.1902
# Collab epoch 44, party 18, error 0.1882
# Collab epoch 44, party 19, error 0.1950
# Collab epoch 44, party 20, error 0.2042
# Collab epoch 44, party 21, error 0.2174
# Collab epoch 44, party 22, error 0.1746
# Collab epoch 44, party 23, error 0.2014
# Collab epoch 44, party 24, error 0.1878
# Collab epoch 44, party 25, error 0.1964
# Collab epoch 44, party 26, error 0.1973
# Collab epoch 44, party 27, error 0.1896
# Collab epoch 45, party 0, error 0.8992
# Collab epoch 45, party 1, error 0.8992
# Collab epoch 45, party 2, error 0.8992
# Collab epoch 45, party 3, error 0.8992
# Collab epoch 45, party 4, error 0.8992
# Collab epoch 45, party 5, error 0.1780
# Collab epoch 45, party 6, error 0.2153
# Collab epoch 45, party 7, error 0.1849
# Collab epoch 45, party 8, error 0.1874
# Collab epoch 45, party 9, error 0.1835
# Collab epoch 45, party 10, error 0.2073
# Collab epoch 45, party 11, error 0.1869
# Collab epoch 45, party 12, error 0.1973
# Collab epoch 45, party 13, error 0.1829
# Collab epoch 45, party 14, error 0.2018
# Collab epoch 45, party 15, error 0.1901
# Collab epoch 45, party 16, error 0.1975
# Collab epoch 45, party 17, error 0.1904
# Collab epoch 45, party 18, error 0.1883
# Collab epoch 45, party 19, error 0.1950
# Collab epoch 45, party 20, error 0.2045
# Collab epoch 45, party 21, error 0.2167
# Collab epoch 45, party 22, error 0.1749
# Collab epoch 45, party 23, error 0.2018
# Collab epoch 45, party 24, error 0.1887
# Collab epoch 45, party 25, error 0.1956
# Collab epoch 45, party 26, error 0.1972
# Collab epoch 45, party 27, error 0.1894
# Collab epoch 46, party 0, error 0.8992
# Collab epoch 46, party 1, error 0.8992
# Collab epoch 46, party 2, error 0.8992
# Collab epoch 46, party 3, error 0.8992
# Collab epoch 46, party 4, error 0.8992
# Collab epoch 46, party 5, error 0.1774
# Collab epoch 46, party 6, error 0.2147
# Collab epoch 46, party 7, error 0.1848
# Collab epoch 46, party 8, error 0.1875
# Collab epoch 46, party 9, error 0.1841
# Collab epoch 46, party 10, error 0.2071
# Collab epoch 46, party 11, error 0.1861
# Collab epoch 46, party 12, error 0.1971
# Collab epoch 46, party 13, error 0.1833
# Collab epoch 46, party 14, error 0.2024
# Collab epoch 46, party 15, error 0.1899
# Collab epoch 46, party 16, error 0.1980
# Collab epoch 46, party 17, error 0.1896
# Collab epoch 46, party 18, error 0.1881
# Collab epoch 46, party 19, error 0.1947
# Collab epoch 46, party 20, error 0.2045
# Collab epoch 46, party 21, error 0.2158
# Collab epoch 46, party 22, error 0.1745
# Collab epoch 46, party 23, error 0.2026
# Collab epoch 46, party 24, error 0.1894
# Collab epoch 46, party 25, error 0.1950
# Collab epoch 46, party 26, error 0.1975
# Collab epoch 46, party 27, error 0.1890
# Collab epoch 47, party 0, error 0.8992
# Collab epoch 47, party 1, error 0.8992
# Collab epoch 47, party 2, error 0.8992
# Collab epoch 47, party 3, error 0.8992
# Collab epoch 47, party 4, error 0.8992
# Collab epoch 47, party 5, error 0.1781
# Collab epoch 47, party 6, error 0.2154
# Collab epoch 47, party 7, error 0.1848
# Collab epoch 47, party 8, error 0.1873
# Collab epoch 47, party 9, error 0.1841
# Collab epoch 47, party 10, error 0.2069
# Collab epoch 47, party 11, error 0.1862
# Collab epoch 47, party 12, error 0.1964
# Collab epoch 47, party 13, error 0.1839
# Collab epoch 47, party 14, error 0.2024
# Collab epoch 47, party 15, error 0.1885
# Collab epoch 47, party 16, error 0.1974
# Collab epoch 47, party 17, error 0.1898
# Collab epoch 47, party 18, error 0.1877
# Collab epoch 47, party 19, error 0.1950
# Collab epoch 47, party 20, error 0.2045
# Collab epoch 47, party 21, error 0.2155
# Collab epoch 47, party 22, error 0.1744
# Collab epoch 47, party 23, error 0.2031
# Collab epoch 47, party 24, error 0.1896
# Collab epoch 47, party 25, error 0.1948
# Collab epoch 47, party 26, error 0.1983
# Collab epoch 47, party 27, error 0.1887
# Collab epoch 48, party 0, error 0.8992
# Collab epoch 48, party 1, error 0.8992
# Collab epoch 48, party 2, error 0.8992
# Collab epoch 48, party 3, error 0.8992
# Collab epoch 48, party 4, error 0.8992
# Collab epoch 48, party 5, error 0.1780
# Collab epoch 48, party 6, error 0.2153
# Collab epoch 48, party 7, error 0.1843
# Collab epoch 48, party 8, error 0.1878
# Collab epoch 48, party 9, error 0.1839
# Collab epoch 48, party 10, error 0.2063
# Collab epoch 48, party 11, error 0.1862
# Collab epoch 48, party 12, error 0.1962
# Collab epoch 48, party 13, error 0.1830
# Collab epoch 48, party 14, error 0.2022
# Collab epoch 48, party 15, error 0.1883
# Collab epoch 48, party 16, error 0.1970
# Collab epoch 48, party 17, error 0.1894
# Collab epoch 48, party 18, error 0.1875
# Collab epoch 48, party 19, error 0.1944
# Collab epoch 48, party 20, error 0.2042
# Collab epoch 48, party 21, error 0.2145
# Collab epoch 48, party 22, error 0.1744
# Collab epoch 48, party 23, error 0.2030
# Collab epoch 48, party 24, error 0.1896
# Collab epoch 48, party 25, error 0.1943
# Collab epoch 48, party 26, error 0.1973
# Collab epoch 48, party 27, error 0.1889
# Collab epoch 49, party 0, error 0.8991
# Collab epoch 49, party 1, error 0.8991
# Collab epoch 49, party 2, error 0.8991
# Collab epoch 49, party 3, error 0.8991
# Collab epoch 49, party 4, error 0.8991
# Collab epoch 49, party 5, error 0.1776
# Collab epoch 49, party 6, error 0.2151
# Collab epoch 49, party 7, error 0.1840
# Collab epoch 49, party 8, error 0.1875
# Collab epoch 49, party 9, error 0.1830
# Collab epoch 49, party 10, error 0.2061
# Collab epoch 49, party 11, error 0.1859
# Collab epoch 49, party 12, error 0.1958
# Collab epoch 49, party 13, error 0.1822
# Collab epoch 49, party 14, error 0.2015
# Collab epoch 49, party 15, error 0.1876
# Collab epoch 49, party 16, error 0.1967
# Collab epoch 49, party 17, error 0.1889
# Collab epoch 49, party 18, error 0.1876
# Collab epoch 49, party 19, error 0.1938
# Collab epoch 49, party 20, error 0.2037
# Collab epoch 49, party 21, error 0.2143
# Collab epoch 49, party 22, error 0.1741
# Collab epoch 49, party 23, error 0.2027
# Collab epoch 49, party 24, error 0.1887
# Collab epoch 49, party 25, error 0.1939
# Collab epoch 49, party 26, error 0.1966
# Collab epoch 49, party 27, error 0.1883
# Finished
