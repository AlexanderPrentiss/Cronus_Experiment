# %% [markdown]
# ### Limit Scope to Only AGR Testing, No Sockets, No Implementation, Just Logits Aggregation

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.datasets as datasets
from scipy.stats import norm

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Stats
class RunningStats:
    """
    Tracks running mean and covariance of vectors in R^C
    using online (streaming) updates.

    This is purely observational — no modification of inputs.
    """

    def __init__(self, dim, device="cpu", eps=1e-6):
        self.dim = dim
        self.device = device
        self.eps = eps

        self.n = 0
        self.mean = torch.zeros(dim, device=device)
        self.M2 = torch.zeros(dim, dim, device=device)  # sum of outer products

    @torch.no_grad()
    def update(self, x):
        """
        x: Tensor of shape (C,)
        """
        self.n += 1
        delta = x - self.mean
        self.mean += delta / self.n
        delta2 = x - self.mean
        self.M2 += torch.outer(delta, delta2)

    def std(self):
        """Per-class std (shape: C)"""
        return torch.sqrt(torch.diag(self.covariance()))


class PublicPredictionObserver:
    """
    Observes public predictions over rounds and maintains
    per-sample statistics if desired.
    """

    def __init__(self, num_classes, device="cpu"):
        self.num_classes = num_classes
        self.device = device
        self.stats = None

    def reset(self):
        self.stats = None

    @torch.no_grad()
    def observe(self, predictions):
        """
        predictions: Tensor of shape (N, C)
        """
        N, C = predictions.shape
        assert C == self.num_classes

        if self.stats is None:
            self.stats = [
                RunningStats(C, device=self.device)
                for _ in range(N)
            ]

        for i in range(N):
            self.stats[i].update(predictions[i])

    def mean(self):
        return torch.stack([s.mean for s in self.stats])
    
    def std(self):
        return torch.stack([s.std for s in self.stats])

    
def inv_phi(n):
    if not (0.0 < n < 1.0):
        raise ValueError("n must be in (0, 1)")
    return norm.ppf(n)

# %%
# BENIGN CLIENT
class MnistModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(784, 256)
        self.lin2 = nn.Linear(256, 64)
        self.lin3 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        return self.lin3(x)

# %%
# MALICIOUS CLIENT
class LIE_Model(nn.Module):
    def __init__(self, active_round, num_malicious, num_models, observer):
        super().__init__()
        self.lin1 = nn.Linear(784, 256)
        self.lin2 = nn.Linear(256, 64)
        self.lin3 = nn.Linear(64, 10)
        self.active_round = active_round
        self.num_rounds = 0
        self.observer = observer
        self.num_malicious = num_malicious
        self.num_models= num_models

    def calculate_v(self):
        z_max = inv_phi(1-(self.num_malicious/self.num_models))
        return self.observer.mean() + z_max

    def forward(self, x):
        if not self.training and self.num_rounds > self.active_round:
            return self.calculate_v()
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        return self.lin3(x)

# %%
def train_ce_fullbatch(model, X, y, optimizer, epochs):
    model.train()
    for _ in range(epochs):
        optimizer.zero_grad()
        logits = model(X)
        loss = F.cross_entropy(logits, y)
        loss.backward()
        optimizer.step()

def train_distill_fullbatch(model, X_pub, teacher_probs, optimizer, epochs, eps=1e-12):
    """
    Distill using teacher probability vectors (Cronus shares prediction vectors).
    Minimize KL(teacher || student) equivalent to cross-entropy with soft targets.
    """
    model.train()
    for _ in range(epochs):
        optimizer.zero_grad()
        student_logits = model(X_pub)
        student_log_probs = F.log_softmax(student_logits, dim=1)
        # KLDivLoss expects log-probs input and probs target
        loss = F.kl_div(student_log_probs, teacher_probs.clamp_min(eps), reduction="batchmean")
        loss.backward()
        optimizer.step()

@torch.no_grad()
def predict_probs(model, X):
    model.eval()
    probs = F.softmax(model(X), dim=1)
    return probs

# -----------------------------
# RobustFilter Aggregation
# - Trims logits
# -----------------------------
def f_cronus(
    logits,
    eps=1e-3,
    lambda_thresh=9.0,
    max_iters=5
):
    """
    Robust Cronus aggregation.

    logits: Tensor [K, N, C]  (models × samples × classes)
    returns: Tensor [N, C]
    """

    K, N, C = logits.shape
    device = logits.device

    agg = torch.zeros(N, C, device=device)

    for n in range(N):

        # Y: [K, C] logits for sample n
        Y = logits[:, n, :]

        # Initial mean
        mu = Y.mean(dim=0)

        for _ in range(max_iters):

            # Centered data
            X = Y - mu

            # If no disagreement, stop
            if X.norm() < 1e-6:
                break

            # Empirical covariance (rank-deficient-safe)
            Sigma = (X.T @ X) / max(len(Y) - 1, 1)

            # Diagonal regularization
            Sigma = Sigma + eps * torch.eye(C, device=device)

            # Eigendecomposition with safety
            try:
                eigvals, eigvecs = torch.linalg.eigh(Sigma)
            except RuntimeError:
                # Covariance too ill-conditioned → skip trimming
                break

            lambda_star = eigvals[-1]

            # If largest eigenvalue small enough, stop trimming
            if lambda_star <= lambda_thresh:
                break

            # Principal direction
            v_star = eigvecs[:, -1]

            # Project samples onto principal direction
            projections = torch.abs((Y - mu) @ v_star)

            max_proj = projections.max()
            if max_proj < 1e-6:
                break

            # Randomized trimming threshold (Cronus)
            T = torch.sqrt(torch.rand(1, device=device)) * max_proj

            mask = projections < T

            # If too few samples left, stop
            if mask.sum() <= 1:
                break

            # Trim and recompute mean
            Y = Y[mask]
            mu = Y.mean(dim=0)

        agg[n] = mu

    return agg

# -----------------------------
# Cronus aggregation (Algorithm 6) + practical modifications used in evaluation
# - stop when lambda_star <= 9
# - deterministic filtering: remove eps/2 fraction each iteration
# - repeat filtering 2 times
# -----------------------------
def cronus_aggregate_probs(
    probs_KNC: torch.Tensor,
    eps: float,
    lambda_thresh: float = 9.0,
    iters: int = 2,
    jitter: float = 1e-6,
):
    """
    probs_KNC: (K, N, C) prediction vectors (probabilities) from K parties
    returns:   (N, C) aggregated prediction vectors

    Implements Algorithm 6's core idea per public sample, and the paper's
    practical variant (deterministic eps/2 filtering, 2 iterations). :contentReference[oaicite:6]{index=6}
    """
    K, N, C = probs_KNC.shape
    out = torch.empty((N, C), device=probs_KNC.device, dtype=probs_KNC.dtype)

    for n in range(N):
        Y = probs_KNC[:, n, :]  # (K, C)

        # Filtering loop (constant 2 iterations in evaluation) :contentReference[oaicite:7]{index=7}
        for _ in range(iters):
            mu = Y.mean(dim=0)

            X = Y - mu
            Sigma = (X.T @ X) / max(Y.shape[0] - 1, 1)
            Sigma = Sigma + jitter * torch.eye(C, device=Y.device, dtype=Y.dtype)

            eigvals, eigvecs = torch.linalg.eigh(Sigma)
            lambda_star = eigvals[-1]
            v_star = eigvecs[:, -1]

            # Stop condition lambda* <= 9 :contentReference[oaicite:8]{index=8}
            if lambda_star <= lambda_thresh:
                break

            # Deterministic filtering: remove eps/2 fraction farthest along v* :contentReference[oaicite:9]{index=9}
            projections = torch.abs((Y - mu) @ v_star)  # (|Y|,)
            m = Y.shape[0]

            drop_frac = eps / 2.0
            drop = int(math.floor(drop_frac * m))

            # If drop would kill the set, stop early
            if drop <= 0 or (m - drop) < 2:
                break

            # Keep the points with smallest projections
            keep_idx = torch.argsort(projections)[: (m - drop)]
            Y = Y[keep_idx]

        out[n] = Y.mean(dim=0)

    # Keep it a valid probability vector (numerical cleanup)
    out = out.clamp_min(0.0)
    out = out / (out.sum(dim=1, keepdim=True) + 1e-12)
    return out

# %%
# Data Initialization
observer = PublicPredictionObserver(num_classes=10, device=device)

mnist_train = datasets.MNIST(root="./data", train=True, download=True)
mnist_test  = datasets.MNIST(root="./data", train=False, download=True)

X_train = mnist_train.data[:50000].float().flatten(1).to(device)
Y_train = mnist_train.targets[:50000].to(device)

X_pub = mnist_train.data[50000:].float().flatten(1).to(device)

X_test = mnist_test.data.float().flatten(1).to(device)
Y_test = mnist_test.targets.to(device)

NUM_PARTIES = 28       
T1 = 50           
T2 = 50             
eps_adv = 0.1           
lambda_thresh = 9.0 
agg_iters = 2   
NUM_MALICIOUS = 5

# Split private data across parties (simple IID split)
per_party = len(X_train) // NUM_PARTIES
perm = torch.randperm(len(X_train), device=device)

X_parts = []
Y_parts = []
for i in range(NUM_PARTIES):
    idx = perm[i * per_party : (i + 1) * per_party]
    X_parts.append(X_train[idx])
    Y_parts.append(Y_train[idx])

if NUM_MALICIOUS > 0:
    models = [LIE_Model(active_round=4, num_malicious=NUM_MALICIOUS, num_models=NUM_PARTIES, observer=observer).to(device) for _ in range(0,NUM_MALICIOUS)]
    models = models + [MnistModel().to(device) for _ in range(NUM_MALICIOUS,NUM_PARTIES)]
else:
    models = [MnistModel().to(device) for _ in range(NUM_MALICIOUS,NUM_PARTIES)]
# --- Initialization phase (private-only, Adam lr=0.0005) :contentReference[oaicite:11]{index=11}
for i in range(NUM_PARTIES):
    opt = Adam(models[i].parameters(), lr=5e-4)
    train_ce_fullbatch(models[i], X_parts[i], Y_parts[i], opt, epochs=T1)

# Initial predictions on public set (Y^0_i = PREDICT(theta_i; Xp)) :contentReference[oaicite:12]{index=12}
with torch.no_grad():
    probs_stack = torch.stack([predict_probs(m, X_pub) for m in models], dim=0)  # (K,N,C)
#Y_bar = cronus_aggregate_probs(probs_stack, eps=eps_adv, lambda_thresh=lambda_thresh, iters=agg_iters)
Y_bar = f_cronus(probs_stack)
observer.observe(Y_bar)

# %%
# --- Collaboration phase
for t in range(T2):
    # Each party updates on Di ∪ Dp (paper does private Adam + public SGD) :contentReference[oaicite:13]{index=13}
    for i in range(NUM_PARTIES):
        opt = SGD(models[i].parameters(), lr=1e-3)
        train_ce_fullbatch(models[i], X_parts[i], Y_parts[i], opt, epochs=1)
        train_distill_fullbatch(models[i], X_pub, Y_bar.detach(), opt, epochs=1)

    # Parties send prediction vectors on Xp; server aggregates to Y_bar^{t+1}
    with torch.no_grad():
        probs_stack = torch.stack([predict_probs(m, X_pub) for m in models], dim=0)
    #Y_bar = cronus_aggregate_probs(probs_stack, eps=eps_adv, lambda_thresh=lambda_thresh, iters=agg_iters)
    Y_bar = f_cronus(probs_stack)
    observer.observe(Y_bar)

    # Logging
    with torch.no_grad():
        for i in range(NUM_PARTIES):
            preds = models[i](X_test).argmax(dim=1)
            err = (preds != Y_test).float().mean().item()
            print(f"Collab epoch {t:02d}, party {i}, error {err:.4f}")

    for i in models[0:NUM_MALICIOUS]:
        i.num_rounds+=1 

print("Finished")
# Out:
# Collab epoch 00, party 0, error 0.1124
# Collab epoch 00, party 1, error 0.1210
# Collab epoch 00, party 2, error 0.1173
# Collab epoch 00, party 3, error 0.1246
# Collab epoch 00, party 4, error 0.1220
# Collab epoch 00, party 5, error 0.1094
# Collab epoch 00, party 6, error 0.1158
# Collab epoch 00, party 7, error 0.1265
# Collab epoch 00, party 8, error 0.1268
# Collab epoch 00, party 9, error 0.1122
# Collab epoch 00, party 10, error 0.1114
# Collab epoch 00, party 11, error 0.1318
# Collab epoch 00, party 12, error 0.1190
# Collab epoch 00, party 13, error 0.1191
# Collab epoch 00, party 14, error 0.1146
# Collab epoch 00, party 15, error 0.1077
# Collab epoch 00, party 16, error 0.1179
# Collab epoch 00, party 17, error 0.1141
# Collab epoch 00, party 18, error 0.1209
# Collab epoch 00, party 19, error 0.1144
# Collab epoch 00, party 20, error 0.1223
# Collab epoch 00, party 21, error 0.1096
# Collab epoch 00, party 22, error 0.1084
# Collab epoch 00, party 23, error 0.1078
# Collab epoch 00, party 24, error 0.1076
# Collab epoch 00, party 25, error 0.1170
# Collab epoch 00, party 26, error 0.1195
# Collab epoch 00, party 27, error 0.1237
# Collab epoch 01, party 0, error 0.1121
# Collab epoch 01, party 1, error 0.1210
# Collab epoch 01, party 2, error 0.1177
# Collab epoch 01, party 3, error 0.1246
# Collab epoch 01, party 4, error 0.1218
# Collab epoch 01, party 5, error 0.1099
# Collab epoch 01, party 6, error 0.1159
# Collab epoch 01, party 7, error 0.1257
# Collab epoch 01, party 8, error 0.1262
# Collab epoch 01, party 9, error 0.1109
# Collab epoch 01, party 10, error 0.1109
# Collab epoch 01, party 11, error 0.1306
# Collab epoch 01, party 12, error 0.1184
# Collab epoch 01, party 13, error 0.1191
# Collab epoch 01, party 14, error 0.1134
# Collab epoch 01, party 15, error 0.1082
# Collab epoch 01, party 16, error 0.1179
# Collab epoch 01, party 17, error 0.1123
# Collab epoch 01, party 18, error 0.1205
# Collab epoch 01, party 19, error 0.1134
# Collab epoch 01, party 20, error 0.1226
# Collab epoch 01, party 21, error 0.1099
# Collab epoch 01, party 22, error 0.1082
# Collab epoch 01, party 23, error 0.1075
# Collab epoch 01, party 24, error 0.1073
# Collab epoch 01, party 25, error 0.1165
# Collab epoch 01, party 26, error 0.1198
# Collab epoch 01, party 27, error 0.1226
# Collab epoch 02, party 0, error 0.1125
# Collab epoch 02, party 1, error 0.1212
# Collab epoch 02, party 2, error 0.1173
# Collab epoch 02, party 3, error 0.1241
# Collab epoch 02, party 4, error 0.1210
# Collab epoch 02, party 5, error 0.1098
# Collab epoch 02, party 6, error 0.1150
# Collab epoch 02, party 7, error 0.1254
# Collab epoch 02, party 8, error 0.1261
# Collab epoch 02, party 9, error 0.1115
# Collab epoch 02, party 10, error 0.1109
# Collab epoch 02, party 11, error 0.1300
# Collab epoch 02, party 12, error 0.1181
# Collab epoch 02, party 13, error 0.1184
# Collab epoch 02, party 14, error 0.1131
# Collab epoch 02, party 15, error 0.1082
# Collab epoch 02, party 16, error 0.1180
# Collab epoch 02, party 17, error 0.1116
# Collab epoch 02, party 18, error 0.1203
# Collab epoch 02, party 19, error 0.1122
# Collab epoch 02, party 20, error 0.1221
# Collab epoch 02, party 21, error 0.1092
# Collab epoch 02, party 22, error 0.1084
# Collab epoch 02, party 23, error 0.1067
# Collab epoch 02, party 24, error 0.1072
# Collab epoch 02, party 25, error 0.1159
# Collab epoch 02, party 26, error 0.1204
# Collab epoch 02, party 27, error 0.1217
# Collab epoch 03, party 0, error 0.1126
# Collab epoch 03, party 1, error 0.1214
# Collab epoch 03, party 2, error 0.1174
# Collab epoch 03, party 3, error 0.1237
# Collab epoch 03, party 4, error 0.1214
# Collab epoch 03, party 5, error 0.1094
# Collab epoch 03, party 6, error 0.1136
# Collab epoch 03, party 7, error 0.1254
# Collab epoch 03, party 8, error 0.1260
# Collab epoch 03, party 9, error 0.1115
# Collab epoch 03, party 10, error 0.1107
# Collab epoch 03, party 11, error 0.1301
# Collab epoch 03, party 12, error 0.1173
# Collab epoch 03, party 13, error 0.1177
# Collab epoch 03, party 14, error 0.1129
# Collab epoch 03, party 15, error 0.1077
# Collab epoch 03, party 16, error 0.1176
# Collab epoch 03, party 17, error 0.1111
# Collab epoch 03, party 18, error 0.1198
# Collab epoch 03, party 19, error 0.1112
# Collab epoch 03, party 20, error 0.1219
# Collab epoch 03, party 21, error 0.1091
# Collab epoch 03, party 22, error 0.1077
# Collab epoch 03, party 23, error 0.1066
# Collab epoch 03, party 24, error 0.1072
# Collab epoch 03, party 25, error 0.1156
# Collab epoch 03, party 26, error 0.1207
# Collab epoch 03, party 27, error 0.1214
# Collab epoch 04, party 0, error 0.1124
# Collab epoch 04, party 1, error 0.1214
# Collab epoch 04, party 2, error 0.1174
# Collab epoch 04, party 3, error 0.1241
# Collab epoch 04, party 4, error 0.1213
# Collab epoch 04, party 5, error 0.1094
# Collab epoch 04, party 6, error 0.1138
# Collab epoch 04, party 7, error 0.1247
# Collab epoch 04, party 8, error 0.1255
# Collab epoch 04, party 9, error 0.1113
# Collab epoch 04, party 10, error 0.1102
# Collab epoch 04, party 11, error 0.1297
# Collab epoch 04, party 12, error 0.1167
# Collab epoch 04, party 13, error 0.1177
# Collab epoch 04, party 14, error 0.1130
# Collab epoch 04, party 15, error 0.1074
# Collab epoch 04, party 16, error 0.1173
# Collab epoch 04, party 17, error 0.1104
# Collab epoch 04, party 18, error 0.1194
# Collab epoch 04, party 19, error 0.1112
# Collab epoch 04, party 20, error 0.1206
# Collab epoch 04, party 21, error 0.1079
# Collab epoch 04, party 22, error 0.1078
# Collab epoch 04, party 23, error 0.1064
# Collab epoch 04, party 24, error 0.1067
# Collab epoch 04, party 25, error 0.1151
# Collab epoch 04, party 26, error 0.1202
# Collab epoch 04, party 27, error 0.1211
# Collab epoch 05, party 0, error 0.9003
# Collab epoch 05, party 1, error 0.9003
# Collab epoch 05, party 2, error 0.9003
# Collab epoch 05, party 3, error 0.9003
# Collab epoch 05, party 4, error 0.9003
# Collab epoch 05, party 5, error 0.1096
# Collab epoch 05, party 6, error 0.1140
# Collab epoch 05, party 7, error 0.1247
# Collab epoch 05, party 8, error 0.1256
# Collab epoch 05, party 9, error 0.1110
# Collab epoch 05, party 10, error 0.1101
# Collab epoch 05, party 11, error 0.1290
# Collab epoch 05, party 12, error 0.1158
# Collab epoch 05, party 13, error 0.1178
# Collab epoch 05, party 14, error 0.1127
# Collab epoch 05, party 15, error 0.1075
# Collab epoch 05, party 16, error 0.1176
# Collab epoch 05, party 17, error 0.1095
# Collab epoch 05, party 18, error 0.1188
# Collab epoch 05, party 19, error 0.1111
# Collab epoch 05, party 20, error 0.1201
# Collab epoch 05, party 21, error 0.1072
# Collab epoch 05, party 22, error 0.1076
# Collab epoch 05, party 23, error 0.1065
# Collab epoch 05, party 24, error 0.1065
# Collab epoch 05, party 25, error 0.1154
# Collab epoch 05, party 26, error 0.1203
# Collab epoch 05, party 27, error 0.1211
# Collab epoch 06, party 0, error 0.9004
# Collab epoch 06, party 1, error 0.9004
# Collab epoch 06, party 2, error 0.9004
# Collab epoch 06, party 3, error 0.9004
# Collab epoch 06, party 4, error 0.9004
# Collab epoch 06, party 5, error 0.1110
# Collab epoch 06, party 6, error 0.1165
# Collab epoch 06, party 7, error 0.1257
# Collab epoch 06, party 8, error 0.1264
# Collab epoch 06, party 9, error 0.1103
# Collab epoch 06, party 10, error 0.1131
# Collab epoch 06, party 11, error 0.1298
# Collab epoch 06, party 12, error 0.1173
# Collab epoch 06, party 13, error 0.1193
# Collab epoch 06, party 14, error 0.1152
# Collab epoch 06, party 15, error 0.1090
# Collab epoch 06, party 16, error 0.1192
# Collab epoch 06, party 17, error 0.1119
# Collab epoch 06, party 18, error 0.1202
# Collab epoch 06, party 19, error 0.1123
# Collab epoch 06, party 20, error 0.1223
# Collab epoch 06, party 21, error 0.1076
# Collab epoch 06, party 22, error 0.1082
# Collab epoch 06, party 23, error 0.1062
# Collab epoch 06, party 24, error 0.1089
# Collab epoch 06, party 25, error 0.1163
# Collab epoch 06, party 26, error 0.1212
# Collab epoch 06, party 27, error 0.1227
# Collab epoch 07, party 0, error 0.9004
# Collab epoch 07, party 1, error 0.9004
# Collab epoch 07, party 2, error 0.9004
# Collab epoch 07, party 3, error 0.9004
# Collab epoch 07, party 4, error 0.9004
# Collab epoch 07, party 5, error 0.1122
# Collab epoch 07, party 6, error 0.1186
# Collab epoch 07, party 7, error 0.1285
# Collab epoch 07, party 8, error 0.1270
# Collab epoch 07, party 9, error 0.1136
# Collab epoch 07, party 10, error 0.1153
# Collab epoch 07, party 11, error 0.1317
# Collab epoch 07, party 12, error 0.1181
# Collab epoch 07, party 13, error 0.1223
# Collab epoch 07, party 14, error 0.1187
# Collab epoch 07, party 15, error 0.1116
# Collab epoch 07, party 16, error 0.1205
# Collab epoch 07, party 17, error 0.1141
# Collab epoch 07, party 18, error 0.1231
# Collab epoch 07, party 19, error 0.1142
# Collab epoch 07, party 20, error 0.1246
# Collab epoch 07, party 21, error 0.1100
# Collab epoch 07, party 22, error 0.1087
# Collab epoch 07, party 23, error 0.1089
# Collab epoch 07, party 24, error 0.1113
# Collab epoch 07, party 25, error 0.1190
# Collab epoch 07, party 26, error 0.1240
# Collab epoch 07, party 27, error 0.1241
# Collab epoch 08, party 0, error 0.9003
# Collab epoch 08, party 1, error 0.9003
# Collab epoch 08, party 2, error 0.9003
# Collab epoch 08, party 3, error 0.9003
# Collab epoch 08, party 4, error 0.9003
# Collab epoch 08, party 5, error 0.1148
# Collab epoch 08, party 6, error 0.1211
# Collab epoch 08, party 7, error 0.1311
# Collab epoch 08, party 8, error 0.1295
# Collab epoch 08, party 9, error 0.1154
# Collab epoch 08, party 10, error 0.1175
# Collab epoch 08, party 11, error 0.1325
# Collab epoch 08, party 12, error 0.1187
# Collab epoch 08, party 13, error 0.1249
# Collab epoch 08, party 14, error 0.1218
# Collab epoch 08, party 15, error 0.1135
# Collab epoch 08, party 16, error 0.1244
# Collab epoch 08, party 17, error 0.1149
# Collab epoch 08, party 18, error 0.1254
# Collab epoch 08, party 19, error 0.1152
# Collab epoch 08, party 20, error 0.1264
# Collab epoch 08, party 21, error 0.1128
# Collab epoch 08, party 22, error 0.1117
# Collab epoch 08, party 23, error 0.1097
# Collab epoch 08, party 24, error 0.1133
# Collab epoch 08, party 25, error 0.1219
# Collab epoch 08, party 26, error 0.1259
# Collab epoch 08, party 27, error 0.1247
# Collab epoch 09, party 0, error 0.9004
# Collab epoch 09, party 1, error 0.9004
# Collab epoch 09, party 2, error 0.9004
# Collab epoch 09, party 3, error 0.9004
# Collab epoch 09, party 4, error 0.9004
# Collab epoch 09, party 5, error 0.1162
# Collab epoch 09, party 6, error 0.1243
# Collab epoch 09, party 7, error 0.1341
# Collab epoch 09, party 8, error 0.1308
# Collab epoch 09, party 9, error 0.1181
# Collab epoch 09, party 10, error 0.1193
# Collab epoch 09, party 11, error 0.1341
# Collab epoch 09, party 12, error 0.1206
# Collab epoch 09, party 13, error 0.1282
# Collab epoch 09, party 14, error 0.1243
# Collab epoch 09, party 15, error 0.1177
# Collab epoch 09, party 16, error 0.1276
# Collab epoch 09, party 17, error 0.1178
# Collab epoch 09, party 18, error 0.1284
# Collab epoch 09, party 19, error 0.1167
# Collab epoch 09, party 20, error 0.1300
# Collab epoch 09, party 21, error 0.1176
# Collab epoch 09, party 22, error 0.1147
# Collab epoch 09, party 23, error 0.1125
# Collab epoch 09, party 24, error 0.1168
# Collab epoch 09, party 25, error 0.1251
# Collab epoch 09, party 26, error 0.1289
# Collab epoch 09, party 27, error 0.1268
# Collab epoch 10, party 0, error 0.9004
# Collab epoch 10, party 1, error 0.9004
# Collab epoch 10, party 2, error 0.9004
# Collab epoch 10, party 3, error 0.9004
# Collab epoch 10, party 4, error 0.9004
# Collab epoch 10, party 5, error 0.1189
# Collab epoch 10, party 6, error 0.1278
# Collab epoch 10, party 7, error 0.1365
# Collab epoch 10, party 8, error 0.1321
# Collab epoch 10, party 9, error 0.1223
# Collab epoch 10, party 10, error 0.1212
# Collab epoch 10, party 11, error 0.1362
# Collab epoch 10, party 12, error 0.1221
# Collab epoch 10, party 13, error 0.1293
# Collab epoch 10, party 14, error 0.1274
# Collab epoch 10, party 15, error 0.1242
# Collab epoch 10, party 16, error 0.1324
# Collab epoch 10, party 17, error 0.1214
# Collab epoch 10, party 18, error 0.1316
# Collab epoch 10, party 19, error 0.1191
# Collab epoch 10, party 20, error 0.1320
# Collab epoch 10, party 21, error 0.1207
# Collab epoch 10, party 22, error 0.1174
# Collab epoch 10, party 23, error 0.1159
# Collab epoch 10, party 24, error 0.1210
# Collab epoch 10, party 25, error 0.1288
# Collab epoch 10, party 26, error 0.1324
# Collab epoch 10, party 27, error 0.1299
# Collab epoch 11, party 0, error 0.9002
# Collab epoch 11, party 1, error 0.9002
# Collab epoch 11, party 2, error 0.9002
# Collab epoch 11, party 3, error 0.9002
# Collab epoch 11, party 4, error 0.9002
# Collab epoch 11, party 5, error 0.1232
# Collab epoch 11, party 6, error 0.1316
# Collab epoch 11, party 7, error 0.1384
# Collab epoch 11, party 8, error 0.1341
# Collab epoch 11, party 9, error 0.1255
# Collab epoch 11, party 10, error 0.1237
# Collab epoch 11, party 11, error 0.1392
# Collab epoch 11, party 12, error 0.1238
# Collab epoch 11, party 13, error 0.1324
# Collab epoch 11, party 14, error 0.1308
# Collab epoch 11, party 15, error 0.1282
# Collab epoch 11, party 16, error 0.1347
# Collab epoch 11, party 17, error 0.1236
# Collab epoch 11, party 18, error 0.1326
# Collab epoch 11, party 19, error 0.1209
# Collab epoch 11, party 20, error 0.1359
# Collab epoch 11, party 21, error 0.1252
# Collab epoch 11, party 22, error 0.1191
# Collab epoch 11, party 23, error 0.1185
# Collab epoch 11, party 24, error 0.1262
# Collab epoch 11, party 25, error 0.1323
# Collab epoch 11, party 26, error 0.1364
# Collab epoch 11, party 27, error 0.1326
# Collab epoch 12, party 0, error 0.9002
# Collab epoch 12, party 1, error 0.9002
# Collab epoch 12, party 2, error 0.9002
# Collab epoch 12, party 3, error 0.9002
# Collab epoch 12, party 4, error 0.9002
# Collab epoch 12, party 5, error 0.1285
# Collab epoch 12, party 6, error 0.1351
# Collab epoch 12, party 7, error 0.1413
# Collab epoch 12, party 8, error 0.1382
# Collab epoch 12, party 9, error 0.1279
# Collab epoch 12, party 10, error 0.1259
# Collab epoch 12, party 11, error 0.1419
# Collab epoch 12, party 12, error 0.1251
# Collab epoch 12, party 13, error 0.1331
# Collab epoch 12, party 14, error 0.1358
# Collab epoch 12, party 15, error 0.1310
# Collab epoch 12, party 16, error 0.1394
# Collab epoch 12, party 17, error 0.1270
# Collab epoch 12, party 18, error 0.1365
# Collab epoch 12, party 19, error 0.1245
# Collab epoch 12, party 20, error 0.1400
# Collab epoch 12, party 21, error 0.1307
# Collab epoch 12, party 22, error 0.1212
# Collab epoch 12, party 23, error 0.1217
# Collab epoch 12, party 24, error 0.1296
# Collab epoch 12, party 25, error 0.1362
# Collab epoch 12, party 26, error 0.1397
# Collab epoch 12, party 27, error 0.1350
# Collab epoch 13, party 0, error 0.9001
# Collab epoch 13, party 1, error 0.9001
# Collab epoch 13, party 2, error 0.9001
# Collab epoch 13, party 3, error 0.9001
# Collab epoch 13, party 4, error 0.9001
# Collab epoch 13, party 5, error 0.1337
# Collab epoch 13, party 6, error 0.1376
# Collab epoch 13, party 7, error 0.1441
# Collab epoch 13, party 8, error 0.1410
# Collab epoch 13, party 9, error 0.1308
# Collab epoch 13, party 10, error 0.1290
# Collab epoch 13, party 11, error 0.1450
# Collab epoch 13, party 12, error 0.1276
# Collab epoch 13, party 13, error 0.1373
# Collab epoch 13, party 14, error 0.1396
# Collab epoch 13, party 15, error 0.1348
# Collab epoch 13, party 16, error 0.1424
# Collab epoch 13, party 17, error 0.1305
# Collab epoch 13, party 18, error 0.1403
# Collab epoch 13, party 19, error 0.1277
# Collab epoch 13, party 20, error 0.1433
# Collab epoch 13, party 21, error 0.1374
# Collab epoch 13, party 22, error 0.1242
# Collab epoch 13, party 23, error 0.1248
# Collab epoch 13, party 24, error 0.1337
# Collab epoch 13, party 25, error 0.1391
# Collab epoch 13, party 26, error 0.1444
# Collab epoch 13, party 27, error 0.1406
# Collab epoch 14, party 0, error 0.9001
# Collab epoch 14, party 1, error 0.9001
# Collab epoch 14, party 2, error 0.9001
# Collab epoch 14, party 3, error 0.9001
# Collab epoch 14, party 4, error 0.9001
# Collab epoch 14, party 5, error 0.1387
# Collab epoch 14, party 6, error 0.1409
# Collab epoch 14, party 7, error 0.1470
# Collab epoch 14, party 8, error 0.1439
# Collab epoch 14, party 9, error 0.1346
# Collab epoch 14, party 10, error 0.1312
# Collab epoch 14, party 11, error 0.1476
# Collab epoch 14, party 12, error 0.1297
# Collab epoch 14, party 13, error 0.1403
# Collab epoch 14, party 14, error 0.1434
# Collab epoch 14, party 15, error 0.1387
# Collab epoch 14, party 16, error 0.1457
# Collab epoch 14, party 17, error 0.1332
# Collab epoch 14, party 18, error 0.1430
# Collab epoch 14, party 19, error 0.1304
# Collab epoch 14, party 20, error 0.1486
# Collab epoch 14, party 21, error 0.1414
# Collab epoch 14, party 22, error 0.1275
# Collab epoch 14, party 23, error 0.1274
# Collab epoch 14, party 24, error 0.1381
# Collab epoch 14, party 25, error 0.1433
# Collab epoch 14, party 26, error 0.1487
# Collab epoch 14, party 27, error 0.1440
# Collab epoch 15, party 0, error 0.9001
# Collab epoch 15, party 1, error 0.9001
# Collab epoch 15, party 2, error 0.9001
# Collab epoch 15, party 3, error 0.9001
# Collab epoch 15, party 4, error 0.9001
# Collab epoch 15, party 5, error 0.1438
# Collab epoch 15, party 6, error 0.1456
# Collab epoch 15, party 7, error 0.1501
# Collab epoch 15, party 8, error 0.1467
# Collab epoch 15, party 9, error 0.1375
# Collab epoch 15, party 10, error 0.1344
# Collab epoch 15, party 11, error 0.1506
# Collab epoch 15, party 12, error 0.1327
# Collab epoch 15, party 13, error 0.1435
# Collab epoch 15, party 14, error 0.1484
# Collab epoch 15, party 15, error 0.1442
# Collab epoch 15, party 16, error 0.1504
# Collab epoch 15, party 17, error 0.1353
# Collab epoch 15, party 18, error 0.1472
# Collab epoch 15, party 19, error 0.1333
# Collab epoch 15, party 20, error 0.1514
# Collab epoch 15, party 21, error 0.1445
# Collab epoch 15, party 22, error 0.1309
# Collab epoch 15, party 23, error 0.1319
# Collab epoch 15, party 24, error 0.1415
# Collab epoch 15, party 25, error 0.1471
# Collab epoch 15, party 26, error 0.1509
# Collab epoch 15, party 27, error 0.1461
# Collab epoch 16, party 0, error 0.9001
# Collab epoch 16, party 1, error 0.9001
# Collab epoch 16, party 2, error 0.9001
# Collab epoch 16, party 3, error 0.9001
# Collab epoch 16, party 4, error 0.9001
# Collab epoch 16, party 5, error 0.1496
# Collab epoch 16, party 6, error 0.1490
# Collab epoch 16, party 7, error 0.1535
# Collab epoch 16, party 8, error 0.1505
# Collab epoch 16, party 9, error 0.1413
# Collab epoch 16, party 10, error 0.1372
# Collab epoch 16, party 11, error 0.1530
# Collab epoch 16, party 12, error 0.1335
# Collab epoch 16, party 13, error 0.1456
# Collab epoch 16, party 14, error 0.1518
# Collab epoch 16, party 15, error 0.1494
# Collab epoch 16, party 16, error 0.1529
# Collab epoch 16, party 17, error 0.1384
# Collab epoch 16, party 18, error 0.1506
# Collab epoch 16, party 19, error 0.1375
# Collab epoch 16, party 20, error 0.1548
# Collab epoch 16, party 21, error 0.1479
# Collab epoch 16, party 22, error 0.1353
# Collab epoch 16, party 23, error 0.1350
# Collab epoch 16, party 24, error 0.1469
# Collab epoch 16, party 25, error 0.1496
# Collab epoch 16, party 26, error 0.1546
# Collab epoch 16, party 27, error 0.1494
# Collab epoch 17, party 0, error 0.9000
# Collab epoch 17, party 1, error 0.9000
# Collab epoch 17, party 2, error 0.9000
# Collab epoch 17, party 3, error 0.9000
# Collab epoch 17, party 4, error 0.9000
# Collab epoch 17, party 5, error 0.1546
# Collab epoch 17, party 6, error 0.1530
# Collab epoch 17, party 7, error 0.1560
# Collab epoch 17, party 8, error 0.1528
# Collab epoch 17, party 9, error 0.1457
# Collab epoch 17, party 10, error 0.1406
# Collab epoch 17, party 11, error 0.1555
# Collab epoch 17, party 12, error 0.1353
# Collab epoch 17, party 13, error 0.1482
# Collab epoch 17, party 14, error 0.1569
# Collab epoch 17, party 15, error 0.1537
# Collab epoch 17, party 16, error 0.1553
# Collab epoch 17, party 17, error 0.1438
# Collab epoch 17, party 18, error 0.1552
# Collab epoch 17, party 19, error 0.1404
# Collab epoch 17, party 20, error 0.1595
# Collab epoch 17, party 21, error 0.1498
# Collab epoch 17, party 22, error 0.1385
# Collab epoch 17, party 23, error 0.1405
# Collab epoch 17, party 24, error 0.1510
# Collab epoch 17, party 25, error 0.1516
# Collab epoch 17, party 26, error 0.1591
# Collab epoch 17, party 27, error 0.1523
# Collab epoch 18, party 0, error 0.8999
# Collab epoch 18, party 1, error 0.8999
# Collab epoch 18, party 2, error 0.8999
# Collab epoch 18, party 3, error 0.8999
# Collab epoch 18, party 4, error 0.8999
# Collab epoch 18, party 5, error 0.1591
# Collab epoch 18, party 6, error 0.1571
# Collab epoch 18, party 7, error 0.1605
# Collab epoch 18, party 8, error 0.1559
# Collab epoch 18, party 9, error 0.1490
# Collab epoch 18, party 10, error 0.1442
# Collab epoch 18, party 11, error 0.1583
# Collab epoch 18, party 12, error 0.1373
# Collab epoch 18, party 13, error 0.1500
# Collab epoch 18, party 14, error 0.1610
# Collab epoch 18, party 15, error 0.1582
# Collab epoch 18, party 16, error 0.1577
# Collab epoch 18, party 17, error 0.1478
# Collab epoch 18, party 18, error 0.1594
# Collab epoch 18, party 19, error 0.1438
# Collab epoch 18, party 20, error 0.1624
# Collab epoch 18, party 21, error 0.1530
# Collab epoch 18, party 22, error 0.1428
# Collab epoch 18, party 23, error 0.1429
# Collab epoch 18, party 24, error 0.1539
# Collab epoch 18, party 25, error 0.1558
# Collab epoch 18, party 26, error 0.1634
# Collab epoch 18, party 27, error 0.1561
# Collab epoch 19, party 0, error 0.9001
# Collab epoch 19, party 1, error 0.9001
# Collab epoch 19, party 2, error 0.9001
# Collab epoch 19, party 3, error 0.9001
# Collab epoch 19, party 4, error 0.9001
# Collab epoch 19, party 5, error 0.1644
# Collab epoch 19, party 6, error 0.1607
# Collab epoch 19, party 7, error 0.1647
# Collab epoch 19, party 8, error 0.1597
# Collab epoch 19, party 9, error 0.1522
# Collab epoch 19, party 10, error 0.1473
# Collab epoch 19, party 11, error 0.1615
# Collab epoch 19, party 12, error 0.1402
# Collab epoch 19, party 13, error 0.1531
# Collab epoch 19, party 14, error 0.1656
# Collab epoch 19, party 15, error 0.1619
# Collab epoch 19, party 16, error 0.1602
# Collab epoch 19, party 17, error 0.1529
# Collab epoch 19, party 18, error 0.1646
# Collab epoch 19, party 19, error 0.1475
# Collab epoch 19, party 20, error 0.1658
# Collab epoch 19, party 21, error 0.1566
# Collab epoch 19, party 22, error 0.1462
# Collab epoch 19, party 23, error 0.1484
# Collab epoch 19, party 24, error 0.1577
# Collab epoch 19, party 25, error 0.1592
# Collab epoch 19, party 26, error 0.1670
# Collab epoch 19, party 27, error 0.1589
# Collab epoch 20, party 0, error 0.9002
# Collab epoch 20, party 1, error 0.9002
# Collab epoch 20, party 2, error 0.9002
# Collab epoch 20, party 3, error 0.9002
# Collab epoch 20, party 4, error 0.9002
# Collab epoch 20, party 5, error 0.1681
# Collab epoch 20, party 6, error 0.1645
# Collab epoch 20, party 7, error 0.1670
# Collab epoch 20, party 8, error 0.1623
# Collab epoch 20, party 9, error 0.1577
# Collab epoch 20, party 10, error 0.1511
# Collab epoch 20, party 11, error 0.1650
# Collab epoch 20, party 12, error 0.1424
# Collab epoch 20, party 13, error 0.1562
# Collab epoch 20, party 14, error 0.1696
# Collab epoch 20, party 15, error 0.1640
# Collab epoch 20, party 16, error 0.1624
# Collab epoch 20, party 17, error 0.1565
# Collab epoch 20, party 18, error 0.1674
# Collab epoch 20, party 19, error 0.1513
# Collab epoch 20, party 20, error 0.1712
# Collab epoch 20, party 21, error 0.1609
# Collab epoch 20, party 22, error 0.1497
# Collab epoch 20, party 23, error 0.1526
# Collab epoch 20, party 24, error 0.1607
# Collab epoch 20, party 25, error 0.1633
# Collab epoch 20, party 26, error 0.1699
# Collab epoch 20, party 27, error 0.1623
# Collab epoch 21, party 0, error 0.9002
# Collab epoch 21, party 1, error 0.9002
# Collab epoch 21, party 2, error 0.9002
# Collab epoch 21, party 3, error 0.9002
# Collab epoch 21, party 4, error 0.9002
# Collab epoch 21, party 5, error 0.1740
# Collab epoch 21, party 6, error 0.1677
# Collab epoch 21, party 7, error 0.1692
# Collab epoch 21, party 8, error 0.1650
# Collab epoch 21, party 9, error 0.1596
# Collab epoch 21, party 10, error 0.1533
# Collab epoch 21, party 11, error 0.1672
# Collab epoch 21, party 12, error 0.1443
# Collab epoch 21, party 13, error 0.1593
# Collab epoch 21, party 14, error 0.1729
# Collab epoch 21, party 15, error 0.1680
# Collab epoch 21, party 16, error 0.1647
# Collab epoch 21, party 17, error 0.1603
# Collab epoch 21, party 18, error 0.1714
# Collab epoch 21, party 19, error 0.1551
# Collab epoch 21, party 20, error 0.1744
# Collab epoch 21, party 21, error 0.1634
# Collab epoch 21, party 22, error 0.1539
# Collab epoch 21, party 23, error 0.1563
# Collab epoch 21, party 24, error 0.1645
# Collab epoch 21, party 25, error 0.1669
# Collab epoch 21, party 26, error 0.1739
# Collab epoch 21, party 27, error 0.1656
# Collab epoch 22, party 0, error 0.9002
# Collab epoch 22, party 1, error 0.9002
# Collab epoch 22, party 2, error 0.9002
# Collab epoch 22, party 3, error 0.9002
# Collab epoch 22, party 4, error 0.9002
# Collab epoch 22, party 5, error 0.1780
# Collab epoch 22, party 6, error 0.1694
# Collab epoch 22, party 7, error 0.1727
# Collab epoch 22, party 8, error 0.1669
# Collab epoch 22, party 9, error 0.1632
# Collab epoch 22, party 10, error 0.1567
# Collab epoch 22, party 11, error 0.1696
# Collab epoch 22, party 12, error 0.1459
# Collab epoch 22, party 13, error 0.1620
# Collab epoch 22, party 14, error 0.1768
# Collab epoch 22, party 15, error 0.1699
# Collab epoch 22, party 16, error 0.1678
# Collab epoch 22, party 17, error 0.1638
# Collab epoch 22, party 18, error 0.1741
# Collab epoch 22, party 19, error 0.1589
# Collab epoch 22, party 20, error 0.1781
# Collab epoch 22, party 21, error 0.1658
# Collab epoch 22, party 22, error 0.1582
# Collab epoch 22, party 23, error 0.1602
# Collab epoch 22, party 24, error 0.1695
# Collab epoch 22, party 25, error 0.1699
# Collab epoch 22, party 26, error 0.1775
# Collab epoch 22, party 27, error 0.1697
# Collab epoch 23, party 0, error 0.9002
# Collab epoch 23, party 1, error 0.9002
# Collab epoch 23, party 2, error 0.9002
# Collab epoch 23, party 3, error 0.9002
# Collab epoch 23, party 4, error 0.9002
# Collab epoch 23, party 5, error 0.1819
# Collab epoch 23, party 6, error 0.1711
# Collab epoch 23, party 7, error 0.1760
# Collab epoch 23, party 8, error 0.1678
# Collab epoch 23, party 9, error 0.1670
# Collab epoch 23, party 10, error 0.1595
# Collab epoch 23, party 11, error 0.1721
# Collab epoch 23, party 12, error 0.1495
# Collab epoch 23, party 13, error 0.1638
# Collab epoch 23, party 14, error 0.1832
# Collab epoch 23, party 15, error 0.1722
# Collab epoch 23, party 16, error 0.1698
# Collab epoch 23, party 17, error 0.1676
# Collab epoch 23, party 18, error 0.1779
# Collab epoch 23, party 19, error 0.1626
# Collab epoch 23, party 20, error 0.1805
# Collab epoch 23, party 21, error 0.1680
# Collab epoch 23, party 22, error 0.1622
# Collab epoch 23, party 23, error 0.1648
# Collab epoch 23, party 24, error 0.1725
# Collab epoch 23, party 25, error 0.1740
# Collab epoch 23, party 26, error 0.1796
# Collab epoch 23, party 27, error 0.1734
# Collab epoch 24, party 0, error 0.9003
# Collab epoch 24, party 1, error 0.9003
# Collab epoch 24, party 2, error 0.9003
# Collab epoch 24, party 3, error 0.9003
# Collab epoch 24, party 4, error 0.9003
# Collab epoch 24, party 5, error 0.1857
# Collab epoch 24, party 6, error 0.1725
# Collab epoch 24, party 7, error 0.1801
# Collab epoch 24, party 8, error 0.1699
# Collab epoch 24, party 9, error 0.1722
# Collab epoch 24, party 10, error 0.1621
# Collab epoch 24, party 11, error 0.1737
# Collab epoch 24, party 12, error 0.1507
# Collab epoch 24, party 13, error 0.1669
# Collab epoch 24, party 14, error 0.1872
# Collab epoch 24, party 15, error 0.1756
# Collab epoch 24, party 16, error 0.1712
# Collab epoch 24, party 17, error 0.1692
# Collab epoch 24, party 18, error 0.1831
# Collab epoch 24, party 19, error 0.1685
# Collab epoch 24, party 20, error 0.1836
# Collab epoch 24, party 21, error 0.1704
# Collab epoch 24, party 22, error 0.1667
# Collab epoch 24, party 23, error 0.1693
# Collab epoch 24, party 24, error 0.1756
# Collab epoch 24, party 25, error 0.1767
# Collab epoch 24, party 26, error 0.1820
# Collab epoch 24, party 27, error 0.1765
# Collab epoch 25, party 0, error 0.9002
# Collab epoch 25, party 1, error 0.9002
# Collab epoch 25, party 2, error 0.9002
# Collab epoch 25, party 3, error 0.9002
# Collab epoch 25, party 4, error 0.9002
# Collab epoch 25, party 5, error 0.1890
# Collab epoch 25, party 6, error 0.1745
# Collab epoch 25, party 7, error 0.1830
# Collab epoch 25, party 8, error 0.1721
# Collab epoch 25, party 9, error 0.1749
# Collab epoch 25, party 10, error 0.1655
# Collab epoch 25, party 11, error 0.1755
# Collab epoch 25, party 12, error 0.1523
# Collab epoch 25, party 13, error 0.1695
# Collab epoch 25, party 14, error 0.1893
# Collab epoch 25, party 15, error 0.1775
# Collab epoch 25, party 16, error 0.1727
# Collab epoch 25, party 17, error 0.1723
# Collab epoch 25, party 18, error 0.1871
# Collab epoch 25, party 19, error 0.1715
# Collab epoch 25, party 20, error 0.1857
# Collab epoch 25, party 21, error 0.1728
# Collab epoch 25, party 22, error 0.1684
# Collab epoch 25, party 23, error 0.1710
# Collab epoch 25, party 24, error 0.1803
# Collab epoch 25, party 25, error 0.1790
# Collab epoch 25, party 26, error 0.1851
# Collab epoch 25, party 27, error 0.1779
# Collab epoch 26, party 0, error 0.9002
# Collab epoch 26, party 1, error 0.9002
# Collab epoch 26, party 2, error 0.9002
# Collab epoch 26, party 3, error 0.9002
# Collab epoch 26, party 4, error 0.9002
# Collab epoch 26, party 5, error 0.1922
# Collab epoch 26, party 6, error 0.1769
# Collab epoch 26, party 7, error 0.1855
# Collab epoch 26, party 8, error 0.1741
# Collab epoch 26, party 9, error 0.1777
# Collab epoch 26, party 10, error 0.1690
# Collab epoch 26, party 11, error 0.1774
# Collab epoch 26, party 12, error 0.1532
# Collab epoch 26, party 13, error 0.1718
# Collab epoch 26, party 14, error 0.1921
# Collab epoch 26, party 15, error 0.1791
# Collab epoch 26, party 16, error 0.1756
# Collab epoch 26, party 17, error 0.1758
# Collab epoch 26, party 18, error 0.1914
# Collab epoch 26, party 19, error 0.1746
# Collab epoch 26, party 20, error 0.1895
# Collab epoch 26, party 21, error 0.1748
# Collab epoch 26, party 22, error 0.1709
# Collab epoch 26, party 23, error 0.1734
# Collab epoch 26, party 24, error 0.1831
# Collab epoch 26, party 25, error 0.1818
# Collab epoch 26, party 26, error 0.1870
# Collab epoch 26, party 27, error 0.1811
# Collab epoch 27, party 0, error 0.9001
# Collab epoch 27, party 1, error 0.9001
# Collab epoch 27, party 2, error 0.9001
# Collab epoch 27, party 3, error 0.9001
# Collab epoch 27, party 4, error 0.9001
# Collab epoch 27, party 5, error 0.1958
# Collab epoch 27, party 6, error 0.1787
# Collab epoch 27, party 7, error 0.1874
# Collab epoch 27, party 8, error 0.1756
# Collab epoch 27, party 9, error 0.1808
# Collab epoch 27, party 10, error 0.1712
# Collab epoch 27, party 11, error 0.1792
# Collab epoch 27, party 12, error 0.1547
# Collab epoch 27, party 13, error 0.1735
# Collab epoch 27, party 14, error 0.1943
# Collab epoch 27, party 15, error 0.1808
# Collab epoch 27, party 16, error 0.1766
# Collab epoch 27, party 17, error 0.1781
# Collab epoch 27, party 18, error 0.1943
# Collab epoch 27, party 19, error 0.1770
# Collab epoch 27, party 20, error 0.1914
# Collab epoch 27, party 21, error 0.1775
# Collab epoch 27, party 22, error 0.1740
# Collab epoch 27, party 23, error 0.1754
# Collab epoch 27, party 24, error 0.1856
# Collab epoch 27, party 25, error 0.1844
# Collab epoch 27, party 26, error 0.1886
# Collab epoch 27, party 27, error 0.1826
# Collab epoch 28, party 0, error 0.9001
# Collab epoch 28, party 1, error 0.9001
# Collab epoch 28, party 2, error 0.9001
# Collab epoch 28, party 3, error 0.9001
# Collab epoch 28, party 4, error 0.9001
# Collab epoch 28, party 5, error 0.1986
# Collab epoch 28, party 6, error 0.1806
# Collab epoch 28, party 7, error 0.1900
# Collab epoch 28, party 8, error 0.1774
# Collab epoch 28, party 9, error 0.1835
# Collab epoch 28, party 10, error 0.1733
# Collab epoch 28, party 11, error 0.1805
# Collab epoch 28, party 12, error 0.1569
# Collab epoch 28, party 13, error 0.1747
# Collab epoch 28, party 14, error 0.1971
# Collab epoch 28, party 15, error 0.1826
# Collab epoch 28, party 16, error 0.1772
# Collab epoch 28, party 17, error 0.1806
# Collab epoch 28, party 18, error 0.1973
# Collab epoch 28, party 19, error 0.1804
# Collab epoch 28, party 20, error 0.1928
# Collab epoch 28, party 21, error 0.1795
# Collab epoch 28, party 22, error 0.1768
# Collab epoch 28, party 23, error 0.1775
# Collab epoch 28, party 24, error 0.1863
# Collab epoch 28, party 25, error 0.1865
# Collab epoch 28, party 26, error 0.1910
# Collab epoch 28, party 27, error 0.1850
# Collab epoch 29, party 0, error 0.9001
# Collab epoch 29, party 1, error 0.9001
# Collab epoch 29, party 2, error 0.9001
# Collab epoch 29, party 3, error 0.9001
# Collab epoch 29, party 4, error 0.9001
# Collab epoch 29, party 5, error 0.2018
# Collab epoch 29, party 6, error 0.1826
# Collab epoch 29, party 7, error 0.1914
# Collab epoch 29, party 8, error 0.1782
# Collab epoch 29, party 9, error 0.1857
# Collab epoch 29, party 10, error 0.1761
# Collab epoch 29, party 11, error 0.1814
# Collab epoch 29, party 12, error 0.1585
# Collab epoch 29, party 13, error 0.1753
# Collab epoch 29, party 14, error 0.1997
# Collab epoch 29, party 15, error 0.1847
# Collab epoch 29, party 16, error 0.1785
# Collab epoch 29, party 17, error 0.1827
# Collab epoch 29, party 18, error 0.2011
# Collab epoch 29, party 19, error 0.1814
# Collab epoch 29, party 20, error 0.1951
# Collab epoch 29, party 21, error 0.1801
# Collab epoch 29, party 22, error 0.1792
# Collab epoch 29, party 23, error 0.1799
# Collab epoch 29, party 24, error 0.1886
# Collab epoch 29, party 25, error 0.1882
# Collab epoch 29, party 26, error 0.1937
# Collab epoch 29, party 27, error 0.1868
# Collab epoch 30, party 0, error 0.9003
# Collab epoch 30, party 1, error 0.9003
# Collab epoch 30, party 2, error 0.9003
# Collab epoch 30, party 3, error 0.9003
# Collab epoch 30, party 4, error 0.9003
# Collab epoch 30, party 5, error 0.2036
# Collab epoch 30, party 6, error 0.1845
# Collab epoch 30, party 7, error 0.1932
# Collab epoch 30, party 8, error 0.1799
# Collab epoch 30, party 9, error 0.1883
# Collab epoch 30, party 10, error 0.1788
# Collab epoch 30, party 11, error 0.1825
# Collab epoch 30, party 12, error 0.1600
# Collab epoch 30, party 13, error 0.1768
# Collab epoch 30, party 14, error 0.2010
# Collab epoch 30, party 15, error 0.1872
# Collab epoch 30, party 16, error 0.1815
# Collab epoch 30, party 17, error 0.1854
# Collab epoch 30, party 18, error 0.2042
# Collab epoch 30, party 19, error 0.1826
# Collab epoch 30, party 20, error 0.1976
# Collab epoch 30, party 21, error 0.1812
# Collab epoch 30, party 22, error 0.1811
# Collab epoch 30, party 23, error 0.1808
# Collab epoch 30, party 24, error 0.1905
# Collab epoch 30, party 25, error 0.1883
# Collab epoch 30, party 26, error 0.1951
# Collab epoch 30, party 27, error 0.1884
# Collab epoch 31, party 0, error 0.9004
# Collab epoch 31, party 1, error 0.9004
# Collab epoch 31, party 2, error 0.9004
# Collab epoch 31, party 3, error 0.9004
# Collab epoch 31, party 4, error 0.9004
# Collab epoch 31, party 5, error 0.2062
# Collab epoch 31, party 6, error 0.1847
# Collab epoch 31, party 7, error 0.1955
# Collab epoch 31, party 8, error 0.1804
# Collab epoch 31, party 9, error 0.1900
# Collab epoch 31, party 10, error 0.1815
# Collab epoch 31, party 11, error 0.1836
# Collab epoch 31, party 12, error 0.1608
# Collab epoch 31, party 13, error 0.1786
# Collab epoch 31, party 14, error 0.2019
# Collab epoch 31, party 15, error 0.1882
# Collab epoch 31, party 16, error 0.1834
# Collab epoch 31, party 17, error 0.1875
# Collab epoch 31, party 18, error 0.2063
# Collab epoch 31, party 19, error 0.1842
# Collab epoch 31, party 20, error 0.1989
# Collab epoch 31, party 21, error 0.1830
# Collab epoch 31, party 22, error 0.1829
# Collab epoch 31, party 23, error 0.1823
# Collab epoch 31, party 24, error 0.1920
# Collab epoch 31, party 25, error 0.1898
# Collab epoch 31, party 26, error 0.1972
# Collab epoch 31, party 27, error 0.1900
# Collab epoch 32, party 0, error 0.9004
# Collab epoch 32, party 1, error 0.9004
# Collab epoch 32, party 2, error 0.9004
# Collab epoch 32, party 3, error 0.9004
# Collab epoch 32, party 4, error 0.9004
# Collab epoch 32, party 5, error 0.2074
# Collab epoch 32, party 6, error 0.1860
# Collab epoch 32, party 7, error 0.1969
# Collab epoch 32, party 8, error 0.1830
# Collab epoch 32, party 9, error 0.1903
# Collab epoch 32, party 10, error 0.1824
# Collab epoch 32, party 11, error 0.1848
# Collab epoch 32, party 12, error 0.1622
# Collab epoch 32, party 13, error 0.1793
# Collab epoch 32, party 14, error 0.2034
# Collab epoch 32, party 15, error 0.1910
# Collab epoch 32, party 16, error 0.1834
# Collab epoch 32, party 17, error 0.1892
# Collab epoch 32, party 18, error 0.2088
# Collab epoch 32, party 19, error 0.1855
# Collab epoch 32, party 20, error 0.1999
# Collab epoch 32, party 21, error 0.1844
# Collab epoch 32, party 22, error 0.1841
# Collab epoch 32, party 23, error 0.1835
# Collab epoch 32, party 24, error 0.1925
# Collab epoch 32, party 25, error 0.1914
# Collab epoch 32, party 26, error 0.1982
# Collab epoch 32, party 27, error 0.1910
# Collab epoch 33, party 0, error 0.9003
# Collab epoch 33, party 1, error 0.9003
# Collab epoch 33, party 2, error 0.9003
# Collab epoch 33, party 3, error 0.9003
# Collab epoch 33, party 4, error 0.9003
# Collab epoch 33, party 5, error 0.2078
# Collab epoch 33, party 6, error 0.1877
# Collab epoch 33, party 7, error 0.1978
# Collab epoch 33, party 8, error 0.1838
# Collab epoch 33, party 9, error 0.1917
# Collab epoch 33, party 10, error 0.1835
# Collab epoch 33, party 11, error 0.1852
# Collab epoch 33, party 12, error 0.1630
# Collab epoch 33, party 13, error 0.1808
# Collab epoch 33, party 14, error 0.2041
# Collab epoch 33, party 15, error 0.1915
# Collab epoch 33, party 16, error 0.1836
# Collab epoch 33, party 17, error 0.1903
# Collab epoch 33, party 18, error 0.2114
# Collab epoch 33, party 19, error 0.1860
# Collab epoch 33, party 20, error 0.2005
# Collab epoch 33, party 21, error 0.1847
# Collab epoch 33, party 22, error 0.1856
# Collab epoch 33, party 23, error 0.1850
# Collab epoch 33, party 24, error 0.1928
# Collab epoch 33, party 25, error 0.1928
# Collab epoch 33, party 26, error 0.1991
# Collab epoch 33, party 27, error 0.1918
# Collab epoch 34, party 0, error 0.9003
# Collab epoch 34, party 1, error 0.9003
# Collab epoch 34, party 2, error 0.9003
# Collab epoch 34, party 3, error 0.9003
# Collab epoch 34, party 4, error 0.9003
# Collab epoch 34, party 5, error 0.2084
# Collab epoch 34, party 6, error 0.1885
# Collab epoch 34, party 7, error 0.1988
# Collab epoch 34, party 8, error 0.1847
# Collab epoch 34, party 9, error 0.1916
# Collab epoch 34, party 10, error 0.1834
# Collab epoch 34, party 11, error 0.1856
# Collab epoch 34, party 12, error 0.1640
# Collab epoch 34, party 13, error 0.1823
# Collab epoch 34, party 14, error 0.2055
# Collab epoch 34, party 15, error 0.1922
# Collab epoch 34, party 16, error 0.1841
# Collab epoch 34, party 17, error 0.1919
# Collab epoch 34, party 18, error 0.2126
# Collab epoch 34, party 19, error 0.1879
# Collab epoch 34, party 20, error 0.2023
# Collab epoch 34, party 21, error 0.1861
# Collab epoch 34, party 22, error 0.1869
# Collab epoch 34, party 23, error 0.1855
# Collab epoch 34, party 24, error 0.1940
# Collab epoch 34, party 25, error 0.1943
# Collab epoch 34, party 26, error 0.2004
# Collab epoch 34, party 27, error 0.1933
# Collab epoch 35, party 0, error 0.9004
# Collab epoch 35, party 1, error 0.9004
# Collab epoch 35, party 2, error 0.9004
# Collab epoch 35, party 3, error 0.9004
# Collab epoch 35, party 4, error 0.9004
# Collab epoch 35, party 5, error 0.2091
# Collab epoch 35, party 6, error 0.1877
# Collab epoch 35, party 7, error 0.1995
# Collab epoch 35, party 8, error 0.1852
# Collab epoch 35, party 9, error 0.1918
# Collab epoch 35, party 10, error 0.1853
# Collab epoch 35, party 11, error 0.1865
# Collab epoch 35, party 12, error 0.1643
# Collab epoch 35, party 13, error 0.1821
# Collab epoch 35, party 14, error 0.2067
# Collab epoch 35, party 15, error 0.1929
# Collab epoch 35, party 16, error 0.1852
# Collab epoch 35, party 17, error 0.1924
# Collab epoch 35, party 18, error 0.2133
# Collab epoch 35, party 19, error 0.1888
# Collab epoch 35, party 20, error 0.2031
# Collab epoch 35, party 21, error 0.1869
# Collab epoch 35, party 22, error 0.1875
# Collab epoch 35, party 23, error 0.1867
# Collab epoch 35, party 24, error 0.1946
# Collab epoch 35, party 25, error 0.1946
# Collab epoch 35, party 26, error 0.2018
# Collab epoch 35, party 27, error 0.1939
# Collab epoch 36, party 0, error 0.9004
# Collab epoch 36, party 1, error 0.9004
# Collab epoch 36, party 2, error 0.9004
# Collab epoch 36, party 3, error 0.9004
# Collab epoch 36, party 4, error 0.9004
# Collab epoch 36, party 5, error 0.2106
# Collab epoch 36, party 6, error 0.1885
# Collab epoch 36, party 7, error 0.2001
# Collab epoch 36, party 8, error 0.1853
# Collab epoch 36, party 9, error 0.1918
# Collab epoch 36, party 10, error 0.1858
# Collab epoch 36, party 11, error 0.1875
# Collab epoch 36, party 12, error 0.1648
# Collab epoch 36, party 13, error 0.1832
# Collab epoch 36, party 14, error 0.2068
# Collab epoch 36, party 15, error 0.1938
# Collab epoch 36, party 16, error 0.1853
# Collab epoch 36, party 17, error 0.1922
# Collab epoch 36, party 18, error 0.2150
# Collab epoch 36, party 19, error 0.1894
# Collab epoch 36, party 20, error 0.2033
# Collab epoch 36, party 21, error 0.1870
# Collab epoch 36, party 22, error 0.1882
# Collab epoch 36, party 23, error 0.1876
# Collab epoch 36, party 24, error 0.1947
# Collab epoch 36, party 25, error 0.1953
# Collab epoch 36, party 26, error 0.2028
# Collab epoch 36, party 27, error 0.1948
# Collab epoch 37, party 0, error 0.9005
# Collab epoch 37, party 1, error 0.9005
# Collab epoch 37, party 2, error 0.9005
# Collab epoch 37, party 3, error 0.9005
# Collab epoch 37, party 4, error 0.9005
# Collab epoch 37, party 5, error 0.2108
# Collab epoch 37, party 6, error 0.1879
# Collab epoch 37, party 7, error 0.2008
# Collab epoch 37, party 8, error 0.1857
# Collab epoch 37, party 9, error 0.1924
# Collab epoch 37, party 10, error 0.1865
# Collab epoch 37, party 11, error 0.1882
# Collab epoch 37, party 12, error 0.1649
# Collab epoch 37, party 13, error 0.1829
# Collab epoch 37, party 14, error 0.2071
# Collab epoch 37, party 15, error 0.1941
# Collab epoch 37, party 16, error 0.1867
# Collab epoch 37, party 17, error 0.1925
# Collab epoch 37, party 18, error 0.2150
# Collab epoch 37, party 19, error 0.1897
# Collab epoch 37, party 20, error 0.2030
# Collab epoch 37, party 21, error 0.1871
# Collab epoch 37, party 22, error 0.1891
# Collab epoch 37, party 23, error 0.1878
# Collab epoch 37, party 24, error 0.1958
# Collab epoch 37, party 25, error 0.1971
# Collab epoch 37, party 26, error 0.2035
# Collab epoch 37, party 27, error 0.1953
# Collab epoch 38, party 0, error 0.9005
# Collab epoch 38, party 1, error 0.9005
# Collab epoch 38, party 2, error 0.9005
# Collab epoch 38, party 3, error 0.9005
# Collab epoch 38, party 4, error 0.9005
# Collab epoch 38, party 5, error 0.2112
# Collab epoch 38, party 6, error 0.1881
# Collab epoch 38, party 7, error 0.2014
# Collab epoch 38, party 8, error 0.1858
# Collab epoch 38, party 9, error 0.1937
# Collab epoch 38, party 10, error 0.1864
# Collab epoch 38, party 11, error 0.1891
# Collab epoch 38, party 12, error 0.1658
# Collab epoch 38, party 13, error 0.1838
# Collab epoch 38, party 14, error 0.2079
# Collab epoch 38, party 15, error 0.1943
# Collab epoch 38, party 16, error 0.1867
# Collab epoch 38, party 17, error 0.1925
# Collab epoch 38, party 18, error 0.2157
# Collab epoch 38, party 19, error 0.1904
# Collab epoch 38, party 20, error 0.2044
# Collab epoch 38, party 21, error 0.1871
# Collab epoch 38, party 22, error 0.1893
# Collab epoch 38, party 23, error 0.1887
# Collab epoch 38, party 24, error 0.1955
# Collab epoch 38, party 25, error 0.1979
# Collab epoch 38, party 26, error 0.2040
# Collab epoch 38, party 27, error 0.1963
# Collab epoch 39, party 0, error 0.9005
# Collab epoch 39, party 1, error 0.9005
# Collab epoch 39, party 2, error 0.9005
# Collab epoch 39, party 3, error 0.9005
# Collab epoch 39, party 4, error 0.9005
# Collab epoch 39, party 5, error 0.2123
# Collab epoch 39, party 6, error 0.1884
# Collab epoch 39, party 7, error 0.2018
# Collab epoch 39, party 8, error 0.1869
# Collab epoch 39, party 9, error 0.1946
# Collab epoch 39, party 10, error 0.1868
# Collab epoch 39, party 11, error 0.1890
# Collab epoch 39, party 12, error 0.1666
# Collab epoch 39, party 13, error 0.1836
# Collab epoch 39, party 14, error 0.2090
# Collab epoch 39, party 15, error 0.1948
# Collab epoch 39, party 16, error 0.1863
# Collab epoch 39, party 17, error 0.1925
# Collab epoch 39, party 18, error 0.2160
# Collab epoch 39, party 19, error 0.1906
# Collab epoch 39, party 20, error 0.2040
# Collab epoch 39, party 21, error 0.1879
# Collab epoch 39, party 22, error 0.1897
# Collab epoch 39, party 23, error 0.1900
# Collab epoch 39, party 24, error 0.1957
# Collab epoch 39, party 25, error 0.1983
# Collab epoch 39, party 26, error 0.2047
# Collab epoch 39, party 27, error 0.1964
# Collab epoch 40, party 0, error 0.9005
# Collab epoch 40, party 1, error 0.9005
# Collab epoch 40, party 2, error 0.9005
# Collab epoch 40, party 3, error 0.9005
# Collab epoch 40, party 4, error 0.9005
# Collab epoch 40, party 5, error 0.2130
# Collab epoch 40, party 6, error 0.1879
# Collab epoch 40, party 7, error 0.2022
# Collab epoch 40, party 8, error 0.1875
# Collab epoch 40, party 9, error 0.1948
# Collab epoch 40, party 10, error 0.1874
# Collab epoch 40, party 11, error 0.1890
# Collab epoch 40, party 12, error 0.1661
# Collab epoch 40, party 13, error 0.1841
# Collab epoch 40, party 14, error 0.2090
# Collab epoch 40, party 15, error 0.1945
# Collab epoch 40, party 16, error 0.1866
# Collab epoch 40, party 17, error 0.1923
# Collab epoch 40, party 18, error 0.2163
# Collab epoch 40, party 19, error 0.1907
# Collab epoch 40, party 20, error 0.2041
# Collab epoch 40, party 21, error 0.1882
# Collab epoch 40, party 22, error 0.1901
# Collab epoch 40, party 23, error 0.1893
# Collab epoch 40, party 24, error 0.1954
# Collab epoch 40, party 25, error 0.1982
# Collab epoch 40, party 26, error 0.2059
# Collab epoch 40, party 27, error 0.1969
# Collab epoch 41, party 0, error 0.9005
# Collab epoch 41, party 1, error 0.9005
# Collab epoch 41, party 2, error 0.9005
# Collab epoch 41, party 3, error 0.9005
# Collab epoch 41, party 4, error 0.9005
# Collab epoch 41, party 5, error 0.2121
# Collab epoch 41, party 6, error 0.1884
# Collab epoch 41, party 7, error 0.2025
# Collab epoch 41, party 8, error 0.1879
# Collab epoch 41, party 9, error 0.1950
# Collab epoch 41, party 10, error 0.1873
# Collab epoch 41, party 11, error 0.1883
# Collab epoch 41, party 12, error 0.1663
# Collab epoch 41, party 13, error 0.1848
# Collab epoch 41, party 14, error 0.2093
# Collab epoch 41, party 15, error 0.1946
# Collab epoch 41, party 16, error 0.1868
# Collab epoch 41, party 17, error 0.1914
# Collab epoch 41, party 18, error 0.2176
# Collab epoch 41, party 19, error 0.1911
# Collab epoch 41, party 20, error 0.2037
# Collab epoch 41, party 21, error 0.1881
# Collab epoch 41, party 22, error 0.1905
# Collab epoch 41, party 23, error 0.1901
# Collab epoch 41, party 24, error 0.1953
# Collab epoch 41, party 25, error 0.1982
# Collab epoch 41, party 26, error 0.2065
# Collab epoch 41, party 27, error 0.1974
# Collab epoch 42, party 0, error 0.9005
# Collab epoch 42, party 1, error 0.9005
# Collab epoch 42, party 2, error 0.9005
# Collab epoch 42, party 3, error 0.9005
# Collab epoch 42, party 4, error 0.9005
# Collab epoch 42, party 5, error 0.2115
# Collab epoch 42, party 6, error 0.1883
# Collab epoch 42, party 7, error 0.2012
# Collab epoch 42, party 8, error 0.1884
# Collab epoch 42, party 9, error 0.1949
# Collab epoch 42, party 10, error 0.1873
# Collab epoch 42, party 11, error 0.1883
# Collab epoch 42, party 12, error 0.1665
# Collab epoch 42, party 13, error 0.1855
# Collab epoch 42, party 14, error 0.2095
# Collab epoch 42, party 15, error 0.1943
# Collab epoch 42, party 16, error 0.1870
# Collab epoch 42, party 17, error 0.1915
# Collab epoch 42, party 18, error 0.2173
# Collab epoch 42, party 19, error 0.1914
# Collab epoch 42, party 20, error 0.2037
# Collab epoch 42, party 21, error 0.1877
# Collab epoch 42, party 22, error 0.1902
# Collab epoch 42, party 23, error 0.1901
# Collab epoch 42, party 24, error 0.1949
# Collab epoch 42, party 25, error 0.1986
# Collab epoch 42, party 26, error 0.2069
# Collab epoch 42, party 27, error 0.1979
# Collab epoch 43, party 0, error 0.9005
# Collab epoch 43, party 1, error 0.9005
# Collab epoch 43, party 2, error 0.9005
# Collab epoch 43, party 3, error 0.9005
# Collab epoch 43, party 4, error 0.9005
# Collab epoch 43, party 5, error 0.2114
# Collab epoch 43, party 6, error 0.1878
# Collab epoch 43, party 7, error 0.2012
# Collab epoch 43, party 8, error 0.1881
# Collab epoch 43, party 9, error 0.1951
# Collab epoch 43, party 10, error 0.1877
# Collab epoch 43, party 11, error 0.1886
# Collab epoch 43, party 12, error 0.1664
# Collab epoch 43, party 13, error 0.1859
# Collab epoch 43, party 14, error 0.2089
# Collab epoch 43, party 15, error 0.1938
# Collab epoch 43, party 16, error 0.1870
# Collab epoch 43, party 17, error 0.1914
# Collab epoch 43, party 18, error 0.2168
# Collab epoch 43, party 19, error 0.1916
# Collab epoch 43, party 20, error 0.2040
# Collab epoch 43, party 21, error 0.1877
# Collab epoch 43, party 22, error 0.1902
# Collab epoch 43, party 23, error 0.1894
# Collab epoch 43, party 24, error 0.1951
# Collab epoch 43, party 25, error 0.1981
# Collab epoch 43, party 26, error 0.2074
# Collab epoch 43, party 27, error 0.1978
# Collab epoch 44, party 0, error 0.9005
# Collab epoch 44, party 1, error 0.9005
# Collab epoch 44, party 2, error 0.9005
# Collab epoch 44, party 3, error 0.9005
# Collab epoch 44, party 4, error 0.9005
# Collab epoch 44, party 5, error 0.2121
# Collab epoch 44, party 6, error 0.1877
# Collab epoch 44, party 7, error 0.2014
# Collab epoch 44, party 8, error 0.1879
# Collab epoch 44, party 9, error 0.1948
# Collab epoch 44, party 10, error 0.1873
# Collab epoch 44, party 11, error 0.1891
# Collab epoch 44, party 12, error 0.1662
# Collab epoch 44, party 13, error 0.1862
# Collab epoch 44, party 14, error 0.2091
# Collab epoch 44, party 15, error 0.1936
# Collab epoch 44, party 16, error 0.1872
# Collab epoch 44, party 17, error 0.1917
# Collab epoch 44, party 18, error 0.2160
# Collab epoch 44, party 19, error 0.1912
# Collab epoch 44, party 20, error 0.2037
# Collab epoch 44, party 21, error 0.1873
# Collab epoch 44, party 22, error 0.1899
# Collab epoch 44, party 23, error 0.1895
# Collab epoch 44, party 24, error 0.1944
# Collab epoch 44, party 25, error 0.1971
# Collab epoch 44, party 26, error 0.2078
# Collab epoch 44, party 27, error 0.1980
# Collab epoch 45, party 0, error 0.9004
# Collab epoch 45, party 1, error 0.9004
# Collab epoch 45, party 2, error 0.9004
# Collab epoch 45, party 3, error 0.9004
# Collab epoch 45, party 4, error 0.9004
# Collab epoch 45, party 5, error 0.2115
# Collab epoch 45, party 6, error 0.1867
# Collab epoch 45, party 7, error 0.2007
# Collab epoch 45, party 8, error 0.1873
# Collab epoch 45, party 9, error 0.1945
# Collab epoch 45, party 10, error 0.1872
# Collab epoch 45, party 11, error 0.1886
# Collab epoch 45, party 12, error 0.1660
# Collab epoch 45, party 13, error 0.1866
# Collab epoch 45, party 14, error 0.2085
# Collab epoch 45, party 15, error 0.1935
# Collab epoch 45, party 16, error 0.1871
# Collab epoch 45, party 17, error 0.1927
# Collab epoch 45, party 18, error 0.2154
# Collab epoch 45, party 19, error 0.1912
# Collab epoch 45, party 20, error 0.2042
# Collab epoch 45, party 21, error 0.1878
# Collab epoch 45, party 22, error 0.1892
# Collab epoch 45, party 23, error 0.1897
# Collab epoch 45, party 24, error 0.1936
# Collab epoch 45, party 25, error 0.1973
# Collab epoch 45, party 26, error 0.2075
# Collab epoch 45, party 27, error 0.1983
# Collab epoch 46, party 0, error 0.9004
# Collab epoch 46, party 1, error 0.9004
# Collab epoch 46, party 2, error 0.9004
# Collab epoch 46, party 3, error 0.9004
# Collab epoch 46, party 4, error 0.9004
# Collab epoch 46, party 5, error 0.2112
# Collab epoch 46, party 6, error 0.1864
# Collab epoch 46, party 7, error 0.2011
# Collab epoch 46, party 8, error 0.1870
# Collab epoch 46, party 9, error 0.1940
# Collab epoch 46, party 10, error 0.1867
# Collab epoch 46, party 11, error 0.1882
# Collab epoch 46, party 12, error 0.1655
# Collab epoch 46, party 13, error 0.1870
# Collab epoch 46, party 14, error 0.2084
# Collab epoch 46, party 15, error 0.1937
# Collab epoch 46, party 16, error 0.1872
# Collab epoch 46, party 17, error 0.1931
# Collab epoch 46, party 18, error 0.2147
# Collab epoch 46, party 19, error 0.1909
# Collab epoch 46, party 20, error 0.2041
# Collab epoch 46, party 21, error 0.1867
# Collab epoch 46, party 22, error 0.1892
# Collab epoch 46, party 23, error 0.1897
# Collab epoch 46, party 24, error 0.1940
# Collab epoch 46, party 25, error 0.1970
# Collab epoch 46, party 26, error 0.2073
# Collab epoch 46, party 27, error 0.1981
# Collab epoch 47, party 0, error 0.9004
# Collab epoch 47, party 1, error 0.9004
# Collab epoch 47, party 2, error 0.9004
# Collab epoch 47, party 3, error 0.9004
# Collab epoch 47, party 4, error 0.9004
# Collab epoch 47, party 5, error 0.2110
# Collab epoch 47, party 6, error 0.1858
# Collab epoch 47, party 7, error 0.2005
# Collab epoch 47, party 8, error 0.1870
# Collab epoch 47, party 9, error 0.1935
# Collab epoch 47, party 10, error 0.1868
# Collab epoch 47, party 11, error 0.1881
# Collab epoch 47, party 12, error 0.1648
# Collab epoch 47, party 13, error 0.1871
# Collab epoch 47, party 14, error 0.2084
# Collab epoch 47, party 15, error 0.1939
# Collab epoch 47, party 16, error 0.1873
# Collab epoch 47, party 17, error 0.1920
# Collab epoch 47, party 18, error 0.2138
# Collab epoch 47, party 19, error 0.1906
# Collab epoch 47, party 20, error 0.2039
# Collab epoch 47, party 21, error 0.1857
# Collab epoch 47, party 22, error 0.1894
# Collab epoch 47, party 23, error 0.1888
# Collab epoch 47, party 24, error 0.1939
# Collab epoch 47, party 25, error 0.1967
# Collab epoch 47, party 26, error 0.2069
# Collab epoch 47, party 27, error 0.1984
# Collab epoch 48, party 0, error 0.9004
# Collab epoch 48, party 1, error 0.9004
# Collab epoch 48, party 2, error 0.9004
# Collab epoch 48, party 3, error 0.9004
# Collab epoch 48, party 4, error 0.9004
# Collab epoch 48, party 5, error 0.2107
# Collab epoch 48, party 6, error 0.1856
# Collab epoch 48, party 7, error 0.1996
# Collab epoch 48, party 8, error 0.1864
# Collab epoch 48, party 9, error 0.1926
# Collab epoch 48, party 10, error 0.1866
# Collab epoch 48, party 11, error 0.1869
# Collab epoch 48, party 12, error 0.1651
# Collab epoch 48, party 13, error 0.1873
# Collab epoch 48, party 14, error 0.2080
# Collab epoch 48, party 15, error 0.1936
# Collab epoch 48, party 16, error 0.1873
# Collab epoch 48, party 17, error 0.1917
# Collab epoch 48, party 18, error 0.2133
# Collab epoch 48, party 19, error 0.1904
# Collab epoch 48, party 20, error 0.2030
# Collab epoch 48, party 21, error 0.1853
# Collab epoch 48, party 22, error 0.1892
# Collab epoch 48, party 23, error 0.1888
# Collab epoch 48, party 24, error 0.1930
# Collab epoch 48, party 25, error 0.1966
# Collab epoch 48, party 26, error 0.2075
# Collab epoch 48, party 27, error 0.1983
# Collab epoch 49, party 0, error 0.9004
# Collab epoch 49, party 1, error 0.9004
# Collab epoch 49, party 2, error 0.9004
# Collab epoch 49, party 3, error 0.9004
# Collab epoch 49, party 4, error 0.9004
# Collab epoch 49, party 5, error 0.2106
# Collab epoch 49, party 6, error 0.1852
# Collab epoch 49, party 7, error 0.1995
# Collab epoch 49, party 8, error 0.1862
# Collab epoch 49, party 9, error 0.1924
# Collab epoch 49, party 10, error 0.1856
# Collab epoch 49, party 11, error 0.1864
# Collab epoch 49, party 12, error 0.1645
# Collab epoch 49, party 13, error 0.1873
# Collab epoch 49, party 14, error 0.2065
# Collab epoch 49, party 15, error 0.1927
# Collab epoch 49, party 16, error 0.1874
# Collab epoch 49, party 17, error 0.1914
# Collab epoch 49, party 18, error 0.2131
# Collab epoch 49, party 19, error 0.1898
# Collab epoch 49, party 20, error 0.2023
# Collab epoch 49, party 21, error 0.1850
# Collab epoch 49, party 22, error 0.1891
# Collab epoch 49, party 23, error 0.1882
# Collab epoch 49, party 24, error 0.1929
# Collab epoch 49, party 25, error 0.1960
# Collab epoch 49, party 26, error 0.2074
# Collab epoch 49, party 27, error 0.1977
# Finished
